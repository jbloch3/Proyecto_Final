# %% [markdown]
# # Extraemos todos los archivos de los zip

# %%
from zipfile import ZipFile

import os
import pandas as pd
import numpy as np

import json

import folium
import folium.plugins
# !pip install utils
# !pip install xmltojson
import requests as req
import xmltojson


from bs4 import BeautifulSoup as bs
#!pip install python-vlc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: utils in /home/jbloch3/.local/lib/python3.8/site-packages (1.0.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xmltojson in /home/jbloch3/.local/lib/python3.8/site-packages (0.2.0)
# Requirement already satisfied: xmltodict in /home/jbloch3/.local/lib/python3.8/site-packages (from xmltojson) (0.12.0)

# %%
archivos = os.listdir()
archivos
# Out:
# ['.git',
#  'takeout-20210614T071504Z-001.zip',
#  'takeout-20210614T071504Z-002.zip',
#  'takeout-20210614T071504Z-004.zip',
#  'takeout-20210614T071504Z-005.zip',
#  'Esquema.docx',
#  'README.md',
#  'takeout-20210614T071504Z-003.zip',
#  'Takeout',
#  '.ipynb_checkpoints',
#  'ProyectoFinal.ipynb',
#  '.gitignore']

# %%
archivos_zip = []
for i in archivos:
    if i.endswith(".zip"):
        archivos_zip.append(i)

# %%
archivos_zip
# Out:
# ['takeout-20210614T071504Z-001.zip',
#  'takeout-20210614T071504Z-002.zip',
#  'takeout-20210614T071504Z-004.zip',
#  'takeout-20210614T071504Z-005.zip',
#  'takeout-20210614T071504Z-003.zip']

# %%
cwd = os.getcwd()

# %%
'''for i in archivos_zip:
    zf = ZipFile(i)
    zf.extractall()'''
# Out:
# 'for i in archivos_zip:\n    zf = ZipFile(i)\n    zf.extractall()'

# %%
os.chdir(cwd + '/' + 'Takeout')

# %%
Takeout_dir = os.getcwd()

# %%
Takeout_dir
# Out:
# '/home/jbloch3/Documents/Proyecto_Final/Takeout'

# %%
os.listdir()
# Out:
# ['Google Fotos',
#  'Chrome',
#  'Search Contributions',
#  'Google\xa0Pay',
#  'Tareas',
#  'Correo',
#  'Cloud Print',
#  'Save',
#  'Google Shopping',
#  'Drive',
#  'Keep',
#  'Hangouts',
#  'Servicio de configuración de dispositivo Android',
#  'Classroom',
#  'archive_browser.html',
#  'Grupos',
#  'Google Play Libros',
#  'Blogger',
#  'Google\xa0My\xa0Business',
#  'Historial de ubicaciones',
#  'Mi actividad',
#  'Calendar',
#  'Cuenta de Google',
#  'Perfil',
#  'Google Workspace Marketplace',
#  'Contactos',
#  'YouTube y YouTube Music',
#  'Noticias',
#  'Servicios de Juegos de Google Play',
#  'Google Play Store',
#  'Google Play Películas',
#  'Maps',
#  'Aplicación Home',
#  'Maps (Tus sitios)']

# %%
#perfil_df = pd.json_normalize("Takeout_dir + '/' + 'Perfil' +'/'+'Perfil.json'")

f = open(Takeout_dir + '/' + 'Perfil' +'/'+'Perfil.json')

# %%
perfil_json = json.load(f)

# %%
nombre = perfil_json['name']['formattedName']
nombre
# Out:
# 'Jaime Bloch'

# %%
perfil_json
# Out:
# {'name': {'givenName': 'Jaime',
#   'familyName': 'Bloch',
#   'formattedName': 'Jaime Bloch'},
#  'displayName': 'Jaime Bloch',
#  'emails': [{'value': 'jaimebloch3@gmail.com'}],
#  'gender': {'type': 'male'}}

# %%
email = perfil_json['emails'][0]['value']

# %%
c = open(Takeout_dir + '/' + 'Chrome' +'/'+'BrowserHistory.json')

# %%
chrome_json = json.load(c)

# %%
df = pd.DataFrame(chrome_json['Browser History'])

# %%
df.url.tail
# Out:
# <bound method NDFrame.tail of 0       https://support.google.com/android/answer/2819582
# 1         https://support.google.com/drive/answer/2424368
# 2       https://support.google.com/android/answer/2819582
# 3       https://support.google.com/android/answer/6193...
# 4       https://www.backmarket.es/samsung-galaxy-s6-32...
#                               ...
# 5518    https://as.com/futbol/2020/06/13/primera/15920...
# 5519    https://as.com/futbol/2020/06/14/primera/15921...
# 5520                                      https://as.com/
# 5521    https://m.eldiario.es/politica/construccion-me...
# 5522                               https://m.eldiario.es/
# Name: url, Length: 5523, dtype: object>

# %%
for i in range(len(df.url)):
    if '//' in df.url[i]:
        df.url[i] = df.url[i].split('//')[1]
# Out:
# <ipython-input-20-1f8a5ad92164>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.url[i] = df.url[i].split('//')[1]

# %%
for i in range(len(df.url)):
    if '/' in df.url[i]:
        df.url[i] = df.url[i].split('/')[0]
# Out:
# <ipython-input-21-1db4e31543ae>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.url[i] = df.url[i].split('/')[0]

# %%
set(df.url)
# Out:
# {'9gag.com',
#  'about:blank',
#  'accounts.google.com',
#  'accounts2.tplinkcloud.com',
#  'aenfismadridpenagrande.com',
#  'altadex.com',
#  'ammos.es',
#  'amp-20minutos-es.cdn.ampproject.org',
#  'amp-cinemablend-com.cdn.ampproject.org',
#  'amp-diariogol-com.cdn.ampproject.org',
#  'amp-economiadigital-es.cdn.ampproject.org',
#  'amp-elmundo-es.cdn.ampproject.org',
#  'amp-elperiodico-com.cdn.ampproject.org',
#  'amp-europapress-es.cdn.ampproject.org',
#  'amp-heraldo-es.cdn.ampproject.org',
#  'amp-jsonline-com.cdn.ampproject.org',
#  'amp-laopiniondemalaga-es.cdn.ampproject.org',
#  'amp-lasexta-com.cdn.ampproject.org',
#  'amp-lne-es.cdn.ampproject.org',
#  'amp-marca-com.cdn.ampproject.org',
#  'amp-milenio-com.cdn.ampproject.org',
#  'amp-reddit-com.cdn.ampproject.org',
#  'amp-rtve-es.cdn.ampproject.org',
#  'amp-ultimahora-es.cdn.ampproject.org',
#  'amp.20minutos.es',
#  'andro4all-com.cdn.ampproject.org',
#  'android-upd.xyz',
#  'anewspost.com',
#  'answers.ea.com',
#  'answers.microsoft.com',
#  'apnews.com',
#  'ar.pinterest.com',
#  'arainfo.org',
#  'argentina.as.com',
#  'as-com.cdn.ampproject.org',
#  'as.com',
#  'asfan.as.com',
#  'aulavirtual.um.es',
#  'badi.com',
#  'bit.ly',
#  'blog-ebrolis-com.cdn.ampproject.org',
#  'blog.lengua-e.com',
#  'blogging-techies.com',
#  'blogs.psychcentral.com',
#  'borjaonline.es',
#  'brainly.lat',
#  'bristolenos.com',
#  'buscandojusticia.es',
#  'cadenaser.com',
#  'canarias.conforama.es',
#  'cartadigitalgratis.es',
#  'cartas.bestfreewifi.com',
#  'casiopea.um.es',
#  'cdn.britannica.com',
#  'centroclinicobetanzos60.es',
#  'cevichedesandia.es',
#  'chile.as.com',
#  'cincodias.elpais.com',
#  'cnnespanol-cnn-com.cdn.ampproject.org',
#  'cocina-casera.com',
#  'cocinaconarte.net',
#  'codstats.net',
#  'colombia.as.com',
#  'companiadeltropico.com',
#  'conelmorrofino.com',
#  'context.reverso.net',
#  'cran.r-project.org',
#  'cuidateplus-marca-com.cdn.ampproject.org',
#  'culturainquieta-com.cdn.ampproject.org',
#  'culturainquieta.com',
#  'debitoor.es',
#  'demonplayingcards.com',
#  'depsicologia-com.cdn.ampproject.org',
#  'depsicologia.com',
#  'diccionariofacil.org',
#  'dle.rae.es',
#  'dlprivateserver.com',
#  'docs.google.com',
#  'dragonball.fandom.com',
#  'ecoembesdudasreciclaje-es.cdn.ampproject.org',
#  'elblogdegriego.blogspot.com',
#  'elclubdelasmujeresinvisibles.com',
#  'elcomidista-elpais-com.cdn.ampproject.org',
#  'elcomidista.elpais.com',
#  'elorigendelsaboreuropeo.com',
#  'eloutput-com.cdn.ampproject.org',
#  'elpais-com.cdn.ampproject.org',
#  'elpais.com',
#  'elredondelito.es',
#  'elretohistorico-com.cdn.ampproject.org',
#  'emagtrends.com',
#  'en.m.wikipedia.org',
#  'entrada.um.es',
#  'entradas.cinesa.es',
#  'entradas.teatroscanal.com',
#  'erasmusu.com',
#  'es-millenium-gg.cdn.ampproject.org',
#  'es.carcarekiosk.com',
#  'es.foursquare.com',
#  'es.hotels.com',
#  'es.jvc.com',
#  'es.m.wikipedia.org',
#  'es.m.wiktionary.org',
#  'es.millenium.gg',
#  'es.oncolink.org',
#  'es.pornhub.com',
#  'es.redbrain.shop',
#  'es.statista.com',
#  'es.surveymonkey.com',
#  'esports.as.com',
#  'estardondeestes.com',
#  'estore.asus.com',
#  'faq.whatsapp.com',
#  'festivalotono.com',
#  'fitcloud.hetangsmart.com',
#  'fortnite.op.gg',
#  'fortnitetracker.com',
#  'fromthepoolside.com',
#  'fruittoday.com',
#  'futuro.aiponline.com.ar',
#  'gamewith.net',
#  'gamingintel.com',
#  'gastroactivity.com',
#  'greekcitytimes-com.cdn.ampproject.org',
#  'greekfestival.gr',
#  'helenizarte.com',
#  'help.instagram.com',
#  'heraldodemexico.com.mx',
#  'herramientas-online.com',
#  'i--d-vice-com.cdn.ampproject.org',
#  'ibb.co',
#  'incidenciaeacnur.surveysparrow.com',
#  'informatediario.com',
#  'juegosadn.eleconomista.es',
#  'khronoshistoria.com',
#  'ktelattikis.gr',
#  'l.eldiario.es',
#  'lacasadelabuelo.es',
#  'lacasatecno.com',
#  'lbunuel.blogspot.com',
#  'lens.google.com',
#  'lentillas.hawkersco.com',
#  'llevatilde-es.cdn.ampproject.org',
#  'locuraviajes-com.cdn.ampproject.org',
#  'login.live.com',
#  'los40.com',
#  'lp.marketingiant.com',
#  'm-eldiario-es.cdn.ampproject.org',
#  'm-publico-es.cdn.ampproject.org',
#  'm.aldia.cat',
#  'm.asivaespana.com',
#  'm.eldiario.es',
#  'm.es.aliexpress.com',
#  'm.facebook.com',
#  'm.filmaffinity.com',
#  'm.forocoches.com',
#  'm.guiadelocio.com',
#  'm.huffingtonpost.es',
#  'm.imdb.com',
#  'm.publico.es',
#  'm.thomann.de',
#  'm.twitch.tv',
#  'm.youtube.com',
#  'm1.caixabank.es',
#  'madridingles-net.cdn.ampproject.org',
#  'madridsecreto.co',
#  'mapasinteractivos.didactalia.net',
#  'masquevapor.com',
#  'meaww-com.cdn.ampproject.org',
#  'medcircle.com',
#  'media.adrcdn.com',
#  'menudeldia.com',
#  'menus.portbluehotels.com',
#  'minepi.com',
#  'mobile.bet365.es',
#  'mobile.twitter.com',
#  'motievi.com',
#  'motor-elpais-com.cdn.ampproject.org',
#  'multitrance.com',
#  'myactivity.google.com',
#  'mycook.es',
#  'n26.com',
#  'newtab',
#  'nymag-com.cdn.ampproject.org',
#  'okdiario-com.cdn.ampproject.org',
#  'okdiario.com',
#  'online.seterra.com',
#  'onlyfans.com',
#  'outlook.live.com',
#  'p.netund.com',
#  'pevgrow.com',
#  'play.acast.com',
#  'play.google.com',
#  'portal.uned.es',
#  'preplacrepe.com',
#  'profile.callofduty.com',
#  'promo.codere.es',
#  'promos.williamhill.es',
#  'proverbia.net',
#  'psicologiaymente.com',
#  'rad.live',
#  'randomsscripts.blogspot.com',
#  'recuperarnoviacom2.com',
#  'register.ubisoft.com',
#  'reparaciones.phonehouse.es',
#  'resultados.as.com',
#  'resultados.elpais.com',
#  'reviewadvisor.net',
#  's.activision.com',
#  'saborgourmet.com',
#  'salonalexsestelo.com',
#  'sas.redsys.es',
#  'sbmmwarzone.com',
#  'screenrant-com.cdn.ampproject.org',
#  'scufgaming.com',
#  'secretaria-virtual.uam.es',
#  'secure.fnac.es',
#  'sede.madrid.es',
#  'sede.sepe.gob.es',
#  'segoviaudaz.es',
#  'segurosdecoche.mapfre.es',
#  'sensiseeds.com',
#  'serhombrenoesdelito.org',
#  'shitmagazine.es',
#  'shop.explodingkittens.com',
#  'sibboventures.com',
#  'sis.redsys.es',
#  'sites.google.com',
#  'sonferrer.com',
#  'specialmemoriesphotography82.pixieset.com',
#  'steamcommunity.com',
#  'sticker.ly',
#  'store.google.com',
#  'store.playstation.com',
#  'store.steampowered.com',
#  'stranded-deep.fandom.com',
#  'support.google.com',
#  't.me',
#  'telefonosatencion.best',
#  'teuladamorairadigital.es',
#  'thedash.es',
#  'thespanishcuisine.com',
#  'thevore.com',
#  'todocomo.com',
#  'tododeedificios.es',
#  'tophotel.news',
#  'transparencia.madrid.es',
#  'travel.gov.gr',
#  'trc.taboola.com',
#  'trends.bibamagazine.fr',
#  'tuexilioenelcaribe.com.es',
#  'u.bicimad.com',
#  'us.as.com',
#  'usuarios.eldiario.es',
#  'venta.renfe.com',
#  'ver.movistarplus.es',
#  'verdesdigitales.com',
#  'verne-elpais-com.cdn.ampproject.org',
#  'versus.com',
#  'vertele.eldiario.es',
#  'vilaritson.com',
#  'vimeo.com',
#  'virgintelco.es',
#  'web.movistar.es',
#  'whyathens.com',
#  'www-abc-es.cdn.ampproject.org',
#  'www-adslzone-net.cdn.ampproject.org',
#  'www-aquariumcostadealmeria-com.cdn.ampproject.org',
#  'www-bbc-com.cdn.ampproject.org',
#  'www-bolsamania-com.cdn.ampproject.org',
#  'www-businessdaily-gr.cdn.ampproject.org',
#  'www-businessinsider-es.cdn.ampproject.org',
#  'www-cocinadelirante-com.cdn.ampproject.org',
#  'www-cope-es.cdn.ampproject.org',
#  'www-dexerto-com.cdn.ampproject.org',
#  'www-dexerto-es.cdn.ampproject.org',
#  'www-diariocordoba-com.cdn.ampproject.org',
#  'www-diariofemenino-com.cdn.ampproject.org',
#  'www-directoalpaladar-com.cdn.ampproject.org',
#  'www-egames-news.cdn.ampproject.org',
#  'www-elconfidencial-com.cdn.ampproject.org',
#  'www-elconfidencialdigital-com.cdn.ampproject.org',
#  'www-eldiario-es.cdn.ampproject.org',
#  'www-elespanol-com.cdn.ampproject.org',
#  'www-elindependiente-com.cdn.ampproject.org',
#  'www-elle-com.cdn.ampproject.org',
#  'www-elnortedecastilla-es.cdn.ampproject.org',
#  'www-elplural-com.cdn.ampproject.org',
#  'www-eonline-com.cdn.ampproject.org',
#  'www-espinof-com.cdn.ampproject.org',
#  'www-esquire-com.cdn.ampproject.org',
#  'www-fisioterapia--online-com.cdn.ampproject.org',
#  'www-fotogramas-es.cdn.ampproject.org',
#  'www-geeksforgeeks-org.cdn.ampproject.org',
#  'www-harpersbazaar-com.cdn.ampproject.org',
#  'www-hobbyconsolas-com.cdn.ampproject.org',
#  'www-idealista-com.cdn.ampproject.org',
#  'www-infobae-com.cdn.ampproject.org',
#  'www-infogate-cl.cdn.ampproject.org',
#  'www-irishmirror-ie.cdn.ampproject.org',
#  'www-latercera-com.cdn.ampproject.org',
#  'www-lavanguardia-com.cdn.ampproject.org',
#  'www-libertaddigital-com.cdn.ampproject.org',
#  'www-libremercado-com.cdn.ampproject.org',
#  'www-metropoliabierta-com.cdn.ampproject.org',
#  'www-millenium-gg.cdn.ampproject.org',
#  'www-movilzona-es.cdn.ampproject.org',
#  'www-mundodeportivo-com.cdn.ampproject.org',
#  'www-news--medical-net.cdn.ampproject.org',
#  'www-newtral-es.cdn.ampproject.org',
#  'www-nytimes-com.cdn.ampproject.org',
#  'www-pcgamesn-com.cdn.ampproject.org',
#  'www-pcworld-es.cdn.ampproject.org',
#  'www-periodistadigital-com.cdn.ampproject.org',
#  'www-pinterest-com.cdn.ampproject.org',
#  'www-pinterest-es.cdn.ampproject.org',
#  'www-polygon-com.cdn.ampproject.org',
#  'www-quever-news.cdn.ampproject.org',
#  'www-recetasderechupete-com.cdn.ampproject.org',
#  'www-sensacine-com.cdn.ampproject.org',
#  'www-solosequenosenada-com.cdn.ampproject.org',
#  'www-sportskeeda-com.cdn.ampproject.org',
#  'www-telemadrid-es.cdn.ampproject.org',
#  'www-tododisca-com.cdn.ampproject.org',
#  'www-tuexpertomovil-com.cdn.ampproject.org',
#  'www-turismoenextremadura-es.cdn.ampproject.org',
#  'www-uppers-es.cdn.ampproject.org',
#  'www-urbandictionary-com.cdn.ampproject.org',
#  'www-vademecum-es.cdn.ampproject.org',
#  'www-vanidades-com.cdn.ampproject.org',
#  'www-vice-com.cdn.ampproject.org',
#  'www-vidaextra-com.cdn.ampproject.org',
#  'www-vox-com.cdn.ampproject.org',
#  'www-xataka-com.cdn.ampproject.org',
#  'www-xatakamovil-com.cdn.ampproject.org',
#  'www-xatakandroid-com.cdn.ampproject.org',
#  'www-yasss-es.cdn.ampproject.org',
#  'www.20minutos.es',
#  'www.3djuegos.com',
#  'www.90min.com',
#  'www.abc.es',
#  'www.acueducto2.com',
#  'www.afiescueladefinanzas.es',
#  'www.aladinia.com',
#  'www.albertosoler.es',
#  'www.amazon.com',
#  'www.amazon.es',
#  'www.aobabogados.com',
#  'www.apple.com',
#  'www.atenas.net',
#  'www.atomicheritage.org',
#  'www.ausonia.es',
#  'www.backmarket.es',
#  'www.bbc.co.uk',
#  'www.bbc.com',
#  'www.bet365.com',
#  'www.bicimad.com',
#  'www.biginfinland.com',
#  'www.blablacar.es',
#  'www.booking.com',
#  'www.bricomart.es',
#  'www.britannica.com',
#  'www.businessinsider.es',
#  'www.caixabank.com',
#  'www.caixabank.es',
#  'www.callofduty.com',
#  'www.caninomag.es',
#  'www.carlsjr.es',
#  'www.carrefour.es',
#  'www.casadani.es',
#  'www.casamento.gr',
#  'www.ccma.cat',
#  'www.chdformacion.es',
#  'www.cinesa.es',
#  'www.cinesrenoir.com',
#  'www.citapreviadnie.es',
#  'www.citapreviapara.com',
#  'www.civitatis.com',
#  'www.clarin.com',
#  'www.clinicabaviera.com',
#  'www.clubpeugeot.es',
#  'www.cnet.com',
#  'www.cocacola.es',
#  'www.cocinacaserayfacil.net',
#  'www.cocinandoconcatman.com',
#  'www.com.org.mx',
#  'www.comiendopipas.com',
#  'www.comunidad.madrid',
#  'www.comunidades.com',
#  'www.consumer.es',
#  'www.consumoteca.com',
#  'www.cronicabalear.es',
#  'www.cronista.com',
#  'www.cuatro.com',
#  'www.dailyedge.ie',
#  'www.dailyforest.com',
#  'www.dailymotion.com',
#  'www.datadoghq.com',
#  'www.davidsuarezoficial.com',
#  'www.dazn.com',
#  'www.decathlon.es',
#  'www.definicionabc.com',
#  'www.deplace.es',
#  'www.diariodeavila.es',
#  'www.diccionariodedudas.com',
#  'www.dictionary.com',
#  'www.diosaplanta.com',
#  'www.directoalpaladar.com',
#  'www.divinacocina.es',
#  'www.doctoralia.es',
#  'www.doithouses.com',
#  'www.dolce-gusto.es',
#  'www.domestika.org',
#  'www.elconfidencial.com',
#  'www.elcorreo.com',
#  'www.elcorteingles.es',
#  'www.eldiario.es',
#  'www.elindependiente.com',
#  'www.elmundo.es',
#  'www.elmundotoday.com',
#  'www.elotrolado.net',
#  'www.elplural.com',
#  'www.enerjet.com.pe',
#  'www.enredando.info',
#  'www.enterat.com',
#  'www.escritores.org',
#  'www.esmadrid.com',
#  'www.factcheck.org',
#  'www.famosos.com',
#  'www.fnac.es',
#  'www.food.com',
#  'www.foodyt.com',
#  'www.formulatv.com',
#  'www.foxnews.com',
#  'www.ft.com',
#  'www.funda.nl',
#  'www.futbolfactory.es',
#  'www.gaes.es',
#  'www.game.es',
#  'www.gamesradar.com',
#  'www.gameyore.com',
#  'www.gfinityesports.com',
#  'www.ginx.tv',
#  'www.girlsbcn.net',
#  'www.gob.pe',
#  'www.goiko.com',
#  'www.google.com',
#  'www.guiadegrecia.com',
#  'www.hispanoteca.eu',
#  'www.huffingtonpost.es',
#  'www.iberia.com',
#  'www.iberley.es',
#  'www.ikea.com',
#  'www.imo.es',
#  'www.indifferentlanguages.com',
#  'www.infinityward.com',
#  'www.informando.es',
#  'www.inquirer.com',
#  'www.instagram.com',
#  'www.inter-rail.org',
#  'www.ironhack.com',
#  'www.jamieoliver.com',
#  'www.juegos-geograficos.com',
#  'www.juguetienda.es',
#  'www.just-eat.es',
#  'www.justwatch.com',
#  'www.laizquierdadiario.com',
#  'www.lamoncloa.gob.es',
#  'www.larazon.es',
#  'www.lariosgin.es',
#  'www.lasexta.com',
#  'www.lavanguardia.com',
#  'www.laverdad.es',
#  'www.lavozdetuperro.com',
#  'www.legalitas.com',
#  'www.libremercado.com',
#  'www.linguee.es',
#  'www.madrid.es',
#  'www.marca.com',
#  'www.masmovil.es',
#  'www.mayoclinic.org',
#  'www.mediamarkt.es',
#  'www.mitjans.es',
#  'www.mmoingame.com',
#  'www.mochileandoporelmundo.com',
#  'www.monicafuste.com',
#  'www.movistar.es',
#  'www.mscbs.gob.es',
#  'www.msn.com',
#  'www.nacex.es',
#  'www.newtral.es',
#  'www.nia.nih.gov',
#  'www.nooddle.es',
#  'www.ocu.org',
#  'www.oftalvist.es',
#  'www.ohmycut.com',
#  'www.ontheissues.org',
#  'www.orichalbaud.com',
#  'www.originscannabis.com',
#  'www.oscaro.es',
#  'www.panoramagriego.gr',
#  'www.pequerecetas.com',
#  'www.periodistadigital.com',
#  'www.pillalas.com',
#  'www.pinterest.de',
#  'www.pinterest.es',
#  'www.piraguaselvado.com',
#  'www.planetadelibros.com',
#  'www.plasticsurgerypractice.com',
#  'www.playstation.com',
#  'www.pokerstarscasino.es',
#  'www.pregunte.es',
#  'www.proyecto-kahlo.com',
#  'www.ps84.es',
#  'www.psicoglobal.com',
#  'www.psicologia-online.com',
#  'www.publico.es',
#  'www.realmadrid.com',
#  'www.realsimple.com',
#  'www.recetas.fitness',
#  'www.recetasderechupete.com',
#  'www.recetasdesbieta.com',
#  'www.reddit.com',
#  'www.renfe.com',
#  'www.rockpapershotgun.com',
#  'www.rtve.es',
#  'www.saberespractico.com',
#  'www.samsung.com',
#  'www.santander.com',
#  'www.sensacine.com',
#  'www.sepe.es',
#  'www.sevillainfo.es',
#  'www.sinonimosgratis.com',
#  'www.sonypictures.com',
#  'www.soolide.com',
#  'www.spth.gob.es',
#  'www.superdeporte.es',
#  'www.t-systems.com',
#  'www.takoaway.com',
#  'www.talquistina.com',
#  'www.tastydetails.com',
#  'www.teatroscanal.com',
#  'www.ted.com',
#  'www.telecinco.es',
#  'www.testeneagrama.com',
#  'www.thedarkimp.com',
#  'www.thejournal.ie',
#  'www.thermorecetas.com',
#  'www.thetrainline.com',
#  'www.tiempo.com',
#  'www.tiendeo.com',
#  'www.timeout.es',
#  'www.toyota.es',
#  'www.toysrus.es',
#  'www.tripadvisor.es',
#  'www.trt.net.tr',
#  'www.tuplaystation.es',
#  'www.uam.es',
#  'www.ultimahora.es',
#  'www.unamamanovata.com',
#  'www.universidadviu.es',
#  'www.unprofesor.com',
#  'www.uolala.com',
#  'www.urbandictionary.com',
#  'www.verdeesvida.es',
#  'www.versus.es',
#  'www.viajeroscallejeros.com',
#  'www.viajeselcorteingles.es',
#  'www.vidaextra.com',
#  'www.vips.es',
#  'www.viva.gr',
#  'www.vivapayments.com',
#  'www.vozpopuli.com',
#  'www.vrhelpnow.com',
#  'www.wikidex.net',
#  'www.wikirioja.com',
#  'www.wordreference.com',
#  'www.xatakandroid.com',
#  'www.xvideos.com',
#  'www.yorokobu.es',
#  'www.youtube.com',
#  'www.zankyou.es',
#  'www.zeelandnet.nl',
#  'www.zendalibros.com',
#  'www1.caixabank.es',
#  'www3.royalmail.com',
#  'xn--el10delbara-v9a.com',
#  'xn--ortopediaortoespaa-30b.es',
#  'yorecurro.es',
#  'yosoymas.masmovil.es',
#  'zacatrus.es',
#  'zhiqingchun.es'}

# %%
df.groupby('url').count().sort_values('title', ascending=False)
# Out:
#                                       page_transition  title  client_id  \
# url
# as.com                                           2189   2189       2189
# www.eldiario.es                                   515    515        515
# www.google.com                                    317    317        317
# mobile.twitter.com                                137    137        137
# www.pinterest.es                                  109    109        109
# ...                                               ...    ...        ...
# www-adslzone-net.cdn.ampproject.org                 1      1          1
# web.movistar.es                                     1      1          1
# virgintelco.es                                      1      1          1
# vilaritson.com                                      1      1          1
# www-idealista-com.cdn.ampproject.org                1      1          1
#
#                                       time_usec
# url
# as.com                                     2189
# www.eldiario.es                             515
# www.google.com                              317
# mobile.twitter.com                          137
# www.pinterest.es                            109
# ...                                         ...
# www-adslzone-net.cdn.ampproject.org           1
# web.movistar.es                               1
# virgintelco.es                                1
# vilaritson.com                                1
# www-idealista-com.cdn.ampproject.org          1
#
# [592 rows x 4 columns]

# %%
Top10URL = df.url.value_counts()[0:10]

# %%
Top10URL
# Out:
# as.com                2189
# www.eldiario.es        515
# www.google.com         317
# mobile.twitter.com     137
# www.pinterest.es       109
# aulavirtual.um.es       91
# resultados.as.com       87
# www.soolide.com         84
# www.xvideos.com         68
# es.m.wikipedia.org      53
# Name: url, dtype: int64

# %%
os. chdir('Servicios de Juegos de Google Play/Juegos/')#cd Servicios de Juegos de Google Play/Juegos/

# %%
ls
# Out:
# 'Best Sniper Legacy_ Dino Hunt'/  'Jet Run_ City Defender'/
# 'CATS_ Crash Arena Turbo Stars'/  'Linebound - Life On The Line'/
# 'Cooking Fever'/                  'Madrid Zombi'/
# 'DEAD TARGET_ Zombie Shooting'/   'Red Ball 4'/
# 'Google Play Games'/              'Warlings_ Armageddon'/
# 'Hero Wars'/

# %%
juegos = os.listdir()

# %%
os. chdir(Takeout_dir)

# %%
r = open(Takeout_dir + '/' + 'Maps (Tus sitios)' +'/'+'Reseñas.json')

# %%
reseñas_json = json.load(r)

# %%
reseñas_json["features"]
# Out:
# [{'geometry': {'coordinates': [-3.6738487, 40.4248464], 'type': 'Point'},
#   'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0x5d92102d0ed91be8',
#    'Location': {'Address': 'Calle de Goya, 99 escalera A, 1D, 28009 Madrid, España',
#     'Business Name': 'Instituto Dental Espinassi & Happy Smile Clinic',
#     'Country Code': 'ES',
#     'Geo Coordinates': {'Latitude': '40.4248464', 'Longitude': '-3.6738487'}},
#    'Published': '2021-05-27T14:18:47.943834Z',
#    'Review Comment': 'Una experiencia estupenda. El sitio está muy bien, me trataron genial y el tratamiento de blancamiento es super efectivo. Muy recomendable :)',
#    'Star Rating': 5},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [-3.7040303, 40.426999], 'type': 'Point'},
#   'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0x78bf2642005218b1',
#    'Location': {'Address': 'Plaza del Dos de Mayo, 28004 Madrid, España',
#     'Business Name': 'Plaza del Dos de Mayo',
#     'Country Code': 'ES',
#     'Geo Coordinates': {'Latitude': '40.4269990', 'Longitude': '-3.7040303'}},
#    'Published': '2021-02-14T12:08:37.717870Z',
#    'Star Rating': 5},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [-3.708749, 40.416807], 'type': 'Point'},
#   'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0x660985eb8d9cede4',
#    'Location': {'Address': 'Calle de las Fuentes, 1, 28013 Madrid, España',
#     'Business Name': 'Ramen Kagura Ópera',
#     'Country Code': 'ES',
#     'Geo Coordinates': {'Latitude': '40.4168070', 'Longitude': '-3.7087490'}},
#    'Published': '2020-12-14T04:10:40.835201Z',
#    'Star Rating': 5},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [-3.7026066, 40.4313091], 'type': 'Point'},
#   'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0x4033c309796d5207',
#    'Location': {'Address': 'Calle de Alburquerque, 5, 28010 Madrid, España',
#     'Business Name': 'Moti e Vi',
#     'Country Code': 'ES',
#     'Geo Coordinates': {'Latitude': '40.4313091', 'Longitude': '-3.7026066'}},
#    'Published': '2020-12-03T11:15:50.821144Z',
#    'Review Comment': 'Cocina de autor buenísima y super barata! Me encantó! Y el ambiente muy agradable.',
#    'Star Rating': 5},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [23.728162, 37.9654788], 'type': 'Point'},
#   'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0x3fe412a82fc813ef',
#    'Location': {'Address': 'Leof. Andrea Siggrou 49, Athina 117 43, Grecia',
#     'Business Name': 'Europcar',
#     'Country Code': 'GR',
#     'Geo Coordinates': {'Latitude': '37.9654788', 'Longitude': '23.7281620'}},
#    'Published': '2020-08-07T12:35:17.480014Z',
#    'Review Comment': 'Horrible experiencia. Nos hicieron pagar un seguro a todo riesgo para poder coger el coche. Después de asegurarnos que nos habian dado un coche mejor, este se rompio a 100km de donde teníamos que devolver el coche. El de la grua dijo que tenía que llevarse el coche, al tiempo que por telefono una chica de Europcar nos decía que como ya habia pasado la hora de entrega, no nos daban coche de sustitución. Todo mal.',
#    'Star Rating': 1},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [-3.59055, 40.4621018], 'type': 'Point'},
#   'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0xc29610f59fa49055',
#    'Location': {'Address': 'Av. de Logroño, 205, 28042 Madrid, España',
#     'Business Name': 'La Caña de Gonzalo',
#     'Country Code': 'ES',
#     'Geo Coordinates': {'Latitude': '40.4621018', 'Longitude': '-3.5905500'}},
#    'Published': '2020-07-12T14:25:06.184531Z',
#    'Review Comment': 'Delicioso! Tienen mi cerveza favorita de barril, la pilsen urquell, y las tapas están buenísimas, recomiendo la minihamburquesa de queso se cabra y cebolla caramelizada. Muy buen trato y muy buen ambiente.',
#    'Star Rating': 5},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [-3.701479, 40.40255], 'type': 'Point'},
#   'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0xe7abde3e60aae0f9',
#    'Location': {'Address': 'Calle de Martín de Vargas, 23, 28005 Madrid, España',
#     'Business Name': 'GRUPO CDM (Madrid)',
#     'Geo Coordinates': {'Latitude': '40.4025500', 'Longitude': '-3.7014790'}},
#    'Published': '2020-01-21T19:14:14.092122Z',
#    'Star Rating': 5},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [-3.6882448, 40.4257422], 'type': 'Point'},
#   'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0x17ecedb11082d9f',
#    'Location': {'Address': 'Calle de Goya, 11, 28001 Madrid, España',
#     'Business Name': 'Cafe & Tapas',
#     'Country Code': 'ES',
#     'Geo Coordinates': {'Latitude': '40.4257422', 'Longitude': '-3.6882448'}},
#    'Published': '2020-01-08T17:11:38.363955Z',
#    'Star Rating': 2},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [-3.7011585, 40.4294192], 'type': 'Point'},
#   'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0x86645b98870d08f',
#    'Location': {'Address': 'Calle de Luchana, 6, 28010 Madrid, España',
#     'Business Name': 'LA CHOCITA SA',
#     'Country Code': 'ES',
#     'Geo Coordinates': {'Latitude': '40.4294192', 'Longitude': '-3.7011585'}},
#    'Published': '2019-02-09T18:24:40.423019Z',
#    'Star Rating': 1},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [-3.7094052, 40.4205735], 'type': 'Point'},
#   'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0xd2817bc697d6de14',
#    'Location': {'Address': 'Calle de la Bola, 12, 28013 Madrid, España',
#     'Business Name': 'A Ri Rang',
#     'Country Code': 'ES',
#     'Geo Coordinates': {'Latitude': '40.4205735', 'Longitude': '-3.7094052'}},
#    'Published': '2019-01-13T13:57:58.404336Z',
#    'Review Comment': 'Muy recomendable. Tienen un plato q se llama bimbabap q suena muy gracioso bien pronunciado',
#    'Star Rating': 5},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [-3.7130877, 40.4420227], 'type': 'Point'},
#   'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0x2b24b073edd5f7f',
#    'Location': {'Address': 'Paseo de S. Fco. de Sales, 36, 28003 Madrid, España',
#     'Business Name': 'Cervecería 100 Montaditos',
#     'Country Code': 'ES',
#     'Geo Coordinates': {'Latitude': '40.4420227', 'Longitude': '-3.7130877'}},
#    'Published': '2018-11-14T20:54:09.362419Z',
#    'Review Comment': 'Tenían Mahou, que aunque esté aguada, es mejor que la Cruzcampo...',
#    'Star Rating': 4},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [-3.7166019, 40.4804702], 'type': 'Point'},
#   'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0x88dd1b5ee1f0dd21',
#    'Location': {'Address': 'Calle de Fermín Caballero, 80, 28035 Madrid, España',
#     'Business Name': 'Mesón Las Vegas',
#     'Country Code': 'ES',
#     'Geo Coordinates': {'Latitude': '40.4804702', 'Longitude': '-3.7166019'}},
#    'Published': '2018-09-21T13:13:12.413484Z',
#    'Star Rating': 5},
#   'type': 'Feature'}]

# %%
df_reseñas = pd.DataFrame(reseñas_json["features"])
df_reseñas
# Out:
#                                              geometry  \
# 0   {'coordinates': [-3.6738487, 40.4248464], 'typ...
# 1   {'coordinates': [-3.7040303, 40.426999], 'type...
# 2   {'coordinates': [-3.708749, 40.416807], 'type'...
# 3   {'coordinates': [-3.7026066, 40.4313091], 'typ...
# 4   {'coordinates': [23.728162, 37.9654788], 'type...
# 5   {'coordinates': [-3.59055, 40.4621018], 'type'...
# 6   {'coordinates': [-3.701479, 40.40255], 'type':...
# 7   {'coordinates': [-3.6882448, 40.4257422], 'typ...
# 8   {'coordinates': [-3.7011585, 40.4294192], 'typ...
# 9   {'coordinates': [-3.7094052, 40.4205735], 'typ...
# 10  {'coordinates': [-3.7130877, 40.4420227], 'typ...
# 11  {'coordinates': [-3.7166019, 40.4804702], 'typ...
#
#                                            properties     type
# 0   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 1   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 2   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 3   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 4   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 5   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 6   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 7   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 8   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 9   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 10  {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 11  {'Google Maps URL': 'https://www.google.com/ma...  Feature

# %%
df_reseñas1 = pd.json_normalize(df_reseñas['properties'])
df_reseñas1
# Out:
#                                       Google Maps URL  \
# 0   https://www.google.com/maps/place//data=!4m2!3...
# 1   https://www.google.com/maps/place//data=!4m2!3...
# 2   https://www.google.com/maps/place//data=!4m2!3...
# 3   https://www.google.com/maps/place//data=!4m2!3...
# 4   https://www.google.com/maps/place//data=!4m2!3...
# 5   https://www.google.com/maps/place//data=!4m2!3...
# 6   https://www.google.com/maps/place//data=!4m2!3...
# 7   https://www.google.com/maps/place//data=!4m2!3...
# 8   https://www.google.com/maps/place//data=!4m2!3...
# 9   https://www.google.com/maps/place//data=!4m2!3...
# 10  https://www.google.com/maps/place//data=!4m2!3...
# 11  https://www.google.com/maps/place//data=!4m2!3...
#
#                       Published  \
# 0   2021-05-27T14:18:47.943834Z
# 1   2021-02-14T12:08:37.717870Z
# 2   2020-12-14T04:10:40.835201Z
# 3   2020-12-03T11:15:50.821144Z
# 4   2020-08-07T12:35:17.480014Z
# 5   2020-07-12T14:25:06.184531Z
# 6   2020-01-21T19:14:14.092122Z
# 7   2020-01-08T17:11:38.363955Z
# 8   2019-02-09T18:24:40.423019Z
# 9   2019-01-13T13:57:58.404336Z
# 10  2018-11-14T20:54:09.362419Z
# 11  2018-09-21T13:13:12.413484Z
#
#                                        Review Comment  Star Rating  \
# 0   Una experiencia estupenda. El sitio está muy b...            5
# 1                                                 NaN            5
# 2                                                 NaN            5
# 3   Cocina de autor buenísima y super barata! Me e...            5
# 4   Horrible experiencia. Nos hicieron pagar un se...            1
# 5   Delicioso! Tienen mi cerveza favorita de barri...            5
# 6                                                 NaN            5
# 7                                                 NaN            2
# 8                                                 NaN            1
# 9   Muy recomendable. Tienen un plato q se llama b...            5
# 10  Tenían Mahou, que aunque esté aguada, es mejor...            4
# 11                                                NaN            5
#
#                                      Location.Address  \
# 0   Calle de Goya, 99 escalera A, 1D, 28009 Madrid...
# 1         Plaza del Dos de Mayo, 28004 Madrid, España
# 2       Calle de las Fuentes, 1, 28013 Madrid, España
# 3      Calle de Alburquerque, 5, 28010 Madrid, España
# 4      Leof. Andrea Siggrou 49, Athina 117 43, Grecia
# 5           Av. de Logroño, 205, 28042 Madrid, España
# 6   Calle de Martín de Vargas, 23, 28005 Madrid, E...
# 7             Calle de Goya, 11, 28001 Madrid, España
# 8           Calle de Luchana, 6, 28010 Madrid, España
# 9          Calle de la Bola, 12, 28013 Madrid, España
# 10  Paseo de S. Fco. de Sales, 36, 28003 Madrid, E...
# 11  Calle de Fermín Caballero, 80, 28035 Madrid, E...
#
#                              Location.Business Name Location.Country Code  \
# 0   Instituto Dental Espinassi & Happy Smile Clinic                    ES
# 1                             Plaza del Dos de Mayo                    ES
# 2                                Ramen Kagura Ópera                    ES
# 3                                         Moti e Vi                    ES
# 4                                          Europcar                    GR
# 5                                La Caña de Gonzalo                    ES
# 6                                GRUPO CDM (Madrid)                   NaN
# 7                                      Cafe & Tapas                    ES
# 8                                     LA CHOCITA SA                    ES
# 9                                         A Ri Rang                    ES
# 10                        Cervecería 100 Montaditos                    ES
# 11                                  Mesón Las Vegas                    ES
#
#    Location.Geo Coordinates.Latitude Location.Geo Coordinates.Longitude
# 0                         40.4248464                         -3.6738487
# 1                         40.4269990                         -3.7040303
# 2                         40.4168070                         -3.7087490
# 3                         40.4313091                         -3.7026066
# 4                         37.9654788                         23.7281620
# 5                         40.4621018                         -3.5905500
# 6                         40.4025500                         -3.7014790
# 7                         40.4257422                         -3.6882448
# 8                         40.4294192                         -3.7011585
# 9                         40.4205735                         -3.7094052
# 10                        40.4420227                         -3.7130877
# 11                        40.4804702                         -3.7166019

# %%
media_reseñas = df_reseñas1['Star Rating'].mean()

# %%
media_reseñas
# Out:
# 4.0

# %%
ubica=df_reseñas1[['Location.Geo Coordinates.Latitude', 'Location.Geo Coordinates.Longitude']].values
ubica
# Out:
# array([['40.4248464', '-3.6738487'],
#        ['40.4269990', '-3.7040303'],
#        ['40.4168070', '-3.7087490'],
#        ['40.4313091', '-3.7026066'],
#        ['37.9654788', '23.7281620'],
#        ['40.4621018', '-3.5905500'],
#        ['40.4025500', '-3.7014790'],
#        ['40.4257422', '-3.6882448'],
#        ['40.4294192', '-3.7011585'],
#        ['40.4205735', '-3.7094052'],
#        ['40.4420227', '-3.7130877'],
#        ['40.4804702', '-3.7166019']], dtype=object)

# %%
'''import gmplot 

gmap = gmplot.GoogleMapPlotter(35, -102, 5)
gmap.scatter(df_reseñas1['Location.Geo Coordinates.Latitude'], df_reseñas1['Location.Geo Coordinates.Longitude'], 'red', size = 10);
#gmap.draw('data/gmplot.html')'''
# Out:
# "import gmplot \n\ngmap = gmplot.GoogleMapPlotter(35, -102, 5)\ngmap.scatter(df_reseñas1['Location.Geo Coordinates.Latitude'], df_reseñas1['Location.Geo Coordinates.Longitude'], 'red', size = 10);\n#gmap.draw('data/gmplot.html')"

# %%
os. chdir('Google Play Libros')
libros = os.listdir()
os. chdir(Takeout_dir)

# %%
libros
# Out:
# ['Don Quijote de la Mancha', 'La Celestina']

# %%
p = open(Takeout_dir + '/' + 'Google Play Películas' +'/'+'Puntuaciones.json')

# %%
peliculas_json = json.load(p)

# %%
peliculas_json
# Out:
# {'ratings': [{'title': 'Dumbo (Doblaje clásico)', 'rating': 'No me gusta'},
#   {'title': 'Dumbo', 'rating': 'No me gusta'}]}

# %%
df_peliculas = pd.DataFrame(peliculas_json['ratings'])
df_peliculas
# Out:
#                      title       rating
# 0  Dumbo (Doblaje clásico)  No me gusta
# 1                    Dumbo  No me gusta

# %%
# !pip install pyquery
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyquery in /home/jbloch3/.local/lib/python3.8/site-packages (1.4.3)
# Requirement already satisfied: lxml>=2.1 in /home/jbloch3/.local/lib/python3.8/site-packages (from pyquery) (4.6.3)
# Requirement already satisfied: cssselect>0.7.9 in /home/jbloch3/.local/lib/python3.8/site-packages (from pyquery) (1.1.0)

# %%
from pyquery import PyQuery

html = open(Takeout_dir + '/YouTube y YouTube Music/historial/historial-de-reproducciones.html', 'r').read() # local html

query = PyQuery(html)
lst= []
for i in range(2000):
    try:
        lst.append(query("a").eq(i).text())
    except: 
        break

# %%
per = query('#text')
per
# Out:
# []

# %%
youtube = pd.DataFrame(lst)
youtube
# Out:
#                                             0
# 0      Informativo matinal express (14/06/21)
# 1                                 Solocomedia
# 2     Order Delivery on Uber Eats | Uber Eats
# 3                            Hola Isabella :D
# 4                                    El Rabos
# ...                                       ...
# 1995                                Skills421
# 1996   Linux & Windows, Instalación Dual Boot
# 1997                                     Fazt
# 1998                           ¿Qué es Linux?
# 1999                                   EDteam
#
# [2000 rows x 1 columns]

# %%
canales = youtube.value_counts()[0:10]
canales
# Out:
# La Resistencia en Movistar+    74
# Cloakzy                        72
# Solocomedia                    34
# Symfuhny                       33
# BennyCentral                   28
# Aydan                          22
# Mundo Maldini                  20
# Inmagic                        19
# I Love Golfing                 18
# Peter DelaG                    16
# dtype: int64

# %%
m = open(Takeout_dir + '/' + 'Maps (Tus sitios)' +'/'+'Reseñas.json')
valoraciones_json = json.load(m)

# %%
valoraciones_json
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'geometry': {'coordinates': [-3.6738487, 40.4248464],
#     'type': 'Point'},
#    'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0x5d92102d0ed91be8',
#     'Location': {'Address': 'Calle de Goya, 99 escalera A, 1D, 28009 Madrid, España',
#      'Business Name': 'Instituto Dental Espinassi & Happy Smile Clinic',
#      'Country Code': 'ES',
#      'Geo Coordinates': {'Latitude': '40.4248464', 'Longitude': '-3.6738487'}},
#     'Published': '2021-05-27T14:18:47.943834Z',
#     'Review Comment': 'Una experiencia estupenda. El sitio está muy bien, me trataron genial y el tratamiento de blancamiento es super efectivo. Muy recomendable :)',
#     'Star Rating': 5},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-3.7040303, 40.426999], 'type': 'Point'},
#    'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0x78bf2642005218b1',
#     'Location': {'Address': 'Plaza del Dos de Mayo, 28004 Madrid, España',
#      'Business Name': 'Plaza del Dos de Mayo',
#      'Country Code': 'ES',
#      'Geo Coordinates': {'Latitude': '40.4269990', 'Longitude': '-3.7040303'}},
#     'Published': '2021-02-14T12:08:37.717870Z',
#     'Star Rating': 5},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-3.708749, 40.416807], 'type': 'Point'},
#    'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0x660985eb8d9cede4',
#     'Location': {'Address': 'Calle de las Fuentes, 1, 28013 Madrid, España',
#      'Business Name': 'Ramen Kagura Ópera',
#      'Country Code': 'ES',
#      'Geo Coordinates': {'Latitude': '40.4168070', 'Longitude': '-3.7087490'}},
#     'Published': '2020-12-14T04:10:40.835201Z',
#     'Star Rating': 5},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-3.7026066, 40.4313091], 'type': 'Point'},
#    'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0x4033c309796d5207',
#     'Location': {'Address': 'Calle de Alburquerque, 5, 28010 Madrid, España',
#      'Business Name': 'Moti e Vi',
#      'Country Code': 'ES',
#      'Geo Coordinates': {'Latitude': '40.4313091', 'Longitude': '-3.7026066'}},
#     'Published': '2020-12-03T11:15:50.821144Z',
#     'Review Comment': 'Cocina de autor buenísima y super barata! Me encantó! Y el ambiente muy agradable.',
#     'Star Rating': 5},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [23.728162, 37.9654788], 'type': 'Point'},
#    'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0x3fe412a82fc813ef',
#     'Location': {'Address': 'Leof. Andrea Siggrou 49, Athina 117 43, Grecia',
#      'Business Name': 'Europcar',
#      'Country Code': 'GR',
#      'Geo Coordinates': {'Latitude': '37.9654788', 'Longitude': '23.7281620'}},
#     'Published': '2020-08-07T12:35:17.480014Z',
#     'Review Comment': 'Horrible experiencia. Nos hicieron pagar un seguro a todo riesgo para poder coger el coche. Después de asegurarnos que nos habian dado un coche mejor, este se rompio a 100km de donde teníamos que devolver el coche. El de la grua dijo que tenía que llevarse el coche, al tiempo que por telefono una chica de Europcar nos decía que como ya habia pasado la hora de entrega, no nos daban coche de sustitución. Todo mal.',
#     'Star Rating': 1},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-3.59055, 40.4621018], 'type': 'Point'},
#    'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0xc29610f59fa49055',
#     'Location': {'Address': 'Av. de Logroño, 205, 28042 Madrid, España',
#      'Business Name': 'La Caña de Gonzalo',
#      'Country Code': 'ES',
#      'Geo Coordinates': {'Latitude': '40.4621018', 'Longitude': '-3.5905500'}},
#     'Published': '2020-07-12T14:25:06.184531Z',
#     'Review Comment': 'Delicioso! Tienen mi cerveza favorita de barril, la pilsen urquell, y las tapas están buenísimas, recomiendo la minihamburquesa de queso se cabra y cebolla caramelizada. Muy buen trato y muy buen ambiente.',
#     'Star Rating': 5},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-3.701479, 40.40255], 'type': 'Point'},
#    'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0xe7abde3e60aae0f9',
#     'Location': {'Address': 'Calle de Martín de Vargas, 23, 28005 Madrid, España',
#      'Business Name': 'GRUPO CDM (Madrid)',
#      'Geo Coordinates': {'Latitude': '40.4025500', 'Longitude': '-3.7014790'}},
#     'Published': '2020-01-21T19:14:14.092122Z',
#     'Star Rating': 5},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-3.6882448, 40.4257422], 'type': 'Point'},
#    'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0x17ecedb11082d9f',
#     'Location': {'Address': 'Calle de Goya, 11, 28001 Madrid, España',
#      'Business Name': 'Cafe & Tapas',
#      'Country Code': 'ES',
#      'Geo Coordinates': {'Latitude': '40.4257422', 'Longitude': '-3.6882448'}},
#     'Published': '2020-01-08T17:11:38.363955Z',
#     'Star Rating': 2},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-3.7011585, 40.4294192], 'type': 'Point'},
#    'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0x86645b98870d08f',
#     'Location': {'Address': 'Calle de Luchana, 6, 28010 Madrid, España',
#      'Business Name': 'LA CHOCITA SA',
#      'Country Code': 'ES',
#      'Geo Coordinates': {'Latitude': '40.4294192', 'Longitude': '-3.7011585'}},
#     'Published': '2019-02-09T18:24:40.423019Z',
#     'Star Rating': 1},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-3.7094052, 40.4205735], 'type': 'Point'},
#    'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0xd2817bc697d6de14',
#     'Location': {'Address': 'Calle de la Bola, 12, 28013 Madrid, España',
#      'Business Name': 'A Ri Rang',
#      'Country Code': 'ES',
#      'Geo Coordinates': {'Latitude': '40.4205735', 'Longitude': '-3.7094052'}},
#     'Published': '2019-01-13T13:57:58.404336Z',
#     'Review Comment': 'Muy recomendable. Tienen un plato q se llama bimbabap q suena muy gracioso bien pronunciado',
#     'Star Rating': 5},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-3.7130877, 40.4420227], 'type': 'Point'},
#    'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0x2b24b073edd5f7f',
#     'Location': {'Address': 'Paseo de S. Fco. de Sales, 36, 28003 Madrid, España',
#      'Business Name': 'Cervecería 100 Montaditos',
#      'Country Code': 'ES',
#      'Geo Coordinates': {'Latitude': '40.4420227', 'Longitude': '-3.7130877'}},
#     'Published': '2018-11-14T20:54:09.362419Z',
#     'Review Comment': 'Tenían Mahou, que aunque esté aguada, es mejor que la Cruzcampo...',
#     'Star Rating': 4},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-3.7166019, 40.4804702], 'type': 'Point'},
#    'properties': {'Google Maps URL': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x0:0x88dd1b5ee1f0dd21',
#     'Location': {'Address': 'Calle de Fermín Caballero, 80, 28035 Madrid, España',
#      'Business Name': 'Mesón Las Vegas',
#      'Country Code': 'ES',
#      'Geo Coordinates': {'Latitude': '40.4804702', 'Longitude': '-3.7166019'}},
#     'Published': '2018-09-21T13:13:12.413484Z',
#     'Star Rating': 5},
#    'type': 'Feature'}]}

# %%
df_valoraciones = pd.DataFrame(valoraciones_json["features"])
df_valoraciones
# Out:
#                                              geometry  \
# 0   {'coordinates': [-3.6738487, 40.4248464], 'typ...
# 1   {'coordinates': [-3.7040303, 40.426999], 'type...
# 2   {'coordinates': [-3.708749, 40.416807], 'type'...
# 3   {'coordinates': [-3.7026066, 40.4313091], 'typ...
# 4   {'coordinates': [23.728162, 37.9654788], 'type...
# 5   {'coordinates': [-3.59055, 40.4621018], 'type'...
# 6   {'coordinates': [-3.701479, 40.40255], 'type':...
# 7   {'coordinates': [-3.6882448, 40.4257422], 'typ...
# 8   {'coordinates': [-3.7011585, 40.4294192], 'typ...
# 9   {'coordinates': [-3.7094052, 40.4205735], 'typ...
# 10  {'coordinates': [-3.7130877, 40.4420227], 'typ...
# 11  {'coordinates': [-3.7166019, 40.4804702], 'typ...
#
#                                            properties     type
# 0   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 1   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 2   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 3   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 4   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 5   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 6   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 7   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 8   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 9   {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 10  {'Google Maps URL': 'https://www.google.com/ma...  Feature
# 11  {'Google Maps URL': 'https://www.google.com/ma...  Feature

# %%
os.chdir(Takeout_dir + '/' + 'Mi actividad' +'/'+'Voz y Audio')

# %%
audios = os.listdir()

# %%
os.chdir(Takeout_dir)

# %%
len(audios)
# Out:
# 974

# %%
ind = np.random.randint(0,len(audios))
import vlc
p = vlc.MediaPlayer(Takeout_dir + '/' + 'Mi actividad' +'/'+'Voz y Audio' + '/'+ audios[ind])
p.play()
# Out:
# 0

# %%
os.chdir(Takeout_dir + '/' + 'Historial de ubicaciones' +'/'+'Semantic Location History')

# %%
años = os.listdir()

# %%
x = open(Takeout_dir + '/' + 'Historial de ubicaciones' +'/'+'Semantic Location History/2016/2016_OCTOBER.json')
prueba_json = json.load(x)

# %%
len(prueba_json['timelineObjects'])
# Out:
# 328

# %%
prueba_json['timelineObjects'][1]['placeVisit']['location']#['latitudeE7']
# Out:
# {'latitudeE7': 404441923,
#  'longitudeE7': -36987280,
#  'placeId': 'ChIJFQpO7_koQg0R0iwzvgVTf3E',
#  'address': 'Calle de Ponzano, 76\n28003 Madrid\nEspaña',
#  'name': 'Picsa',
#  'sourceInfo': {'deviceTag': 773610100},
#  'locationConfidence': 99.99132}

# %%
df_prueba = pd.DataFrame(prueba_json['timelineObjects'])
df_prueba
# Out:
#                                        activitySegment  \
# 0    {'startLocation': {'latitudeE7': 404234350, 'l...
# 1                                                  NaN
# 2    {'startLocation': {'latitudeE7': 404441923, 'l...
# 3                                                  NaN
# 4    {'startLocation': {'latitudeE7': 404450648, 'l...
# ..                                                 ...
# 323                                                NaN
# 324  {'startLocation': {'latitudeE7': 404264938, 'l...
# 325                                                NaN
# 326  {'startLocation': {'latitudeE7': 404245942, 'l...
# 327                                                NaN
#
#                                             placeVisit
# 0                                                  NaN
# 1    {'location': {'latitudeE7': 404441923, 'longit...
# 2                                                  NaN
# 3    {'location': {'latitudeE7': 404450648, 'longit...
# 4                                                  NaN
# ..                                                 ...
# 323  {'location': {'latitudeE7': 404264938, 'longit...
# 324                                                NaN
# 325  {'location': {'latitudeE7': 404245942, 'longit...
# 326                                                NaN
# 327  {'location': {'latitudeE7': 410467800, 'longit...
#
# [328 rows x 2 columns]

# %%
df_prueba2 = pd.json_normalize(df_prueba.placeVisit)
df_prueba2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-d545ba6cdb77> in <module>
# ----> 1 df_prueba2 = pd.json_normalize(df_prueba.placeVisit)
#       2 df_prueba2
#
# ~/.local/lib/python3.8/site-packages/pandas/io/json/_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     268
#     269     if record_path is None:
# --> 270         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     271             # naive normalization, this is idempotent for flat records
#     272             # and potentially will inflate the data considerably for
#
# ~/.local/lib/python3.8/site-packages/pandas/io/json/_normalize.py in <genexpr>(.0)
#     268
#     269     if record_path is None:
# --> 270         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     271             # naive normalization, this is idempotent for flat records
#     272             # and potentially will inflate the data considerably for
#
# AttributeError: 'float' object has no attribute 'values'

# %%
años
# Out:
# ['2021', '2019', '2015', '2020', '2017', '2016', '2018']

# %%
os.chdir(Takeout_dir + '/' + 'Historial de ubicaciones' +'/'+'Semantic Location History/')

# %%
años = os.listdir()

# %%
lst= []
for i in años:
    os.chdir(Takeout_dir + '/' + 'Historial de ubicaciones' +'/'+'Semantic Location History/' + i)
    meses = os.listdir()   
    for j in meses:
        x = open(Takeout_dir + '/' + 'Historial de ubicaciones' +'/'+'Semantic Location History/'+i+'/'+ j)
        prueba_json = json.load(x)
        for k in range(len(prueba_json['timelineObjects'])):
            try:
                lst.append((prueba_json['timelineObjects'][k]['placeVisit']['location']['latitudeE7'], prueba_json['timelineObjects'][k]['placeVisit']['location']['longitudeE7'], i, j))
            except:
                pass

# %%
lst
# Out:
# [(404245976, -36945293, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (405072661, -36956392, '2021', '2021_MARCH.json'),
#  (404583111, -36899247, '2021', '2021_MARCH.json'),
#  (404277841, -36959238, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404277841, -36959238, '2021', '2021_MARCH.json'),
#  (404294746, -36985680, '2021', '2021_MARCH.json'),
#  (404419100, -36966808, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404304434, -36717929, '2021', '2021_MARCH.json'),
#  (404245976, -36945293, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404468030, -36923000, '2021', '2021_MARCH.json'),
#  (404006498, -36921406, '2021', '2021_MARCH.json'),
#  (403998874, -36947396, '2021', '2021_MARCH.json'),
#  (404003907, -36927656, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404251153, -36805799, '2021', '2021_MARCH.json'),
#  (404245976, -36945293, '2021', '2021_MARCH.json'),
#  (404346327, -37083248, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404258584, -36812889, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404268682, -36960092, '2021', '2021_MARCH.json'),
#  (404261558, -37018814, '2021', '2021_MARCH.json'),
#  (404267621, -37028750, '2021', '2021_MARCH.json'),
#  (404290600, -37021800, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404257590, -36890932, '2021', '2021_MARCH.json'),
#  (404245976, -36945293, '2021', '2021_MARCH.json'),
#  (404252100, -36912500, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404246256, -36782296, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404084512, -37007072, '2021', '2021_MARCH.json'),
#  (404108488, -37032356, '2021', '2021_MARCH.json'),
#  (404105898, -37059791, '2021', '2021_MARCH.json'),
#  (404096367, -37035841, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404243221, -36959004, '2021', '2021_MARCH.json'),
#  (404245976, -36945293, '2021', '2021_MARCH.json'),
#  (404270990, -36992645, '2021', '2021_MARCH.json'),
#  (404313091, -37026066, '2021', '2021_MARCH.json'),
#  (404290600, -37021800, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404263552, -36927541, '2021', '2021_MARCH.json'),
#  (404346327, -37083248, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404259518, -36778376, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404245976, -36945293, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404346327, -37083248, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404334982, -37006417, '2021', '2021_MARCH.json'),
#  (404313091, -37026066, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404234001, -36909306, '2021', '2021_MARCH.json'),
#  (404245976, -36945293, '2021', '2021_MARCH.json'),
#  (404255400, -37039910, '2021', '2021_MARCH.json'),
#  (404269990, -37040303, '2021', '2021_MARCH.json'),
#  (404297126, -37013648, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404226462, -37091334, '2021', '2021_MARCH.json'),
#  (404245976, -36945293, '2021', '2021_MARCH.json'),
#  (404268079, -36986831, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404253037, -36737723, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404245976, -36945293, '2021', '2021_MARCH.json'),
#  (404290600, -37021800, '2021', '2021_MARCH.json'),
#  (404015131, -36864236, '2021', '2021_MARCH.json'),
#  (404014858, -36896244, '2021', '2021_MARCH.json'),
#  (404037703, -36934005, '2021', '2021_MARCH.json'),
#  (404065461, -36931665, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (404245976, -36945293, '2021', '2021_MARCH.json'),
#  (404310454, -37027044, '2021', '2021_MARCH.json'),
#  (404264077, -36812895, '2021', '2021_MARCH.json'),
#  (403923149, -36985035, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (404248464, -36738487, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (403923149, -36985035, '2021', '2021_JUNE.json'),
#  (403950705, -36963522, '2021', '2021_JUNE.json'),
#  (403923149, -36985035, '2021', '2021_JUNE.json'),
#  (403911290, -36951562, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (403923149, -36985035, '2021', '2021_JUNE.json'),
#  (403911290, -36951562, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (404313091, -37026066, '2021', '2021_JUNE.json'),
#  (404301431, -37017557, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (403923149, -36985097, '2021', '2021_JUNE.json'),
#  (403917202, -36952015, '2021', '2021_JUNE.json'),
#  (403923149, -36985097, '2021', '2021_JUNE.json'),
#  (403941394, -36982631, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (404290600, -37021800, '2021', '2021_JUNE.json'),
#  (404281270, -37039650, '2021', '2021_JUNE.json'),
#  (404268114, -37024967, '2021', '2021_JUNE.json'),
#  (404322425, -37006061, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (404246256, -36782296, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (404277841, -36959238, '2021', '2021_JUNE.json'),
#  (404267621, -37028750, '2021', '2021_JUNE.json'),
#  (404277841, -36959238, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (404246336, -36948537, '2021', '2021_JUNE.json'),
#  (406401229, -31854288, '2021', '2021_JUNE.json'),
#  (404245976, -36945293, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (403923149, -36985109, '2021', '2021_JUNE.json'),
#  (404089714, -36925985, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (403923149, -36985109, '2021', '2021_JUNE.json'),
#  (403998874, -36947396, '2021', '2021_JUNE.json'),
#  (403920659, -36961166, '2021', '2021_JUNE.json'),
#  (403928831, -36971407, '2021', '2021_JUNE.json'),
#  (403911290, -36951562, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (403923187, -36985109, '2021', '2021_JUNE.json'),
#  (403933333, -36977778, '2021', '2021_JUNE.json'),
#  (403923187, -36985109, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (404230733, -36797763, '2021', '2021_JUNE.json'),
#  (404369830, -37039710, '2021', '2021_JUNE.json'),
#  (404353194, -37041376, '2021', '2021_JUNE.json'),
#  (404294140, -37019880, '2021', '2021_JUNE.json'),
#  (404337332, -37025502, '2021', '2021_JUNE.json'),
#  (404290600, -37021800, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (403923187, -36985109, '2021', '2021_JUNE.json'),
#  (403911290, -36951562, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (404258995, -36878997, '2021', '2021_JUNE.json'),
#  (403923187, -36985109, '2021', '2021_JUNE.json'),
#  (403908753, -37014217, '2021', '2021_JUNE.json'),
#  (403923111, -36985233, '2021', '2021_JUNE.json'),
#  (403911290, -36951562, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (404255570, -36615640, '2021', '2021_JUNE.json'),
#  (404307700, -36642800, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (404230733, -36797763, '2021', '2021_JUNE.json'),
#  (404190270, -37052540, '2021', '2021_JUNE.json'),
#  (403911290, -36951562, '2021', '2021_JUNE.json'),
#  (403998874, -36947396, '2021', '2021_JUNE.json'),
#  (404305595, -37160778, '2021', '2021_JUNE.json'),
#  (404251286, -36795703, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (404313091, -37026066, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JUNE.json'),
#  (403923111, -36985233, '2021', '2021_JUNE.json'),
#  (404264077, -36812895, '2021', '2021_JANUARY.json'),
#  (404261494, -37011780, '2021', '2021_JANUARY.json'),
#  (404266036, -36962117, '2021', '2021_JANUARY.json'),
#  (404264077, -36812895, '2021', '2021_JANUARY.json'),
#  (404254729, -37018412, '2021', '2021_JANUARY.json'),
#  (404300880, -37152529, '2021', '2021_JANUARY.json'),
#  (404264077, -36812895, '2021', '2021_JANUARY.json'),
#  (404264077, -36812895, '2021', '2021_JANUARY.json'),
#  (404346327, -37083248, '2021', '2021_JANUARY.json'),
#  (404298696, -37060568, '2021', '2021_JANUARY.json'),
#  (404264077, -36812895, '2021', '2021_JANUARY.json'),
#  (404251153, -36805799, '2021', '2021_JANUARY.json'),
#  (404346327, -37083248, '2021', '2021_JANUARY.json'),
#  (404264077, -36812895, '2021', '2021_JANUARY.json'),
#  (404264077, -36812895, '2021', '2021_JANUARY.json'),
#  (404390676, -37137747, '2021', '2021_JANUARY.json'),
#  (404309106, -37073472, '2021', '2021_JANUARY.json'),
#  (404390676, -37137747, '2021', '2021_JANUARY.json'),
#  (404264077, -36812895, '2021', '2021_JANUARY.json'),
#  (404254167, -36787472, '2021', '2021_JANUARY.json'),
#  (404264077, -36812895, '2021', '2021_JANUARY.json'),
#  (404346327, -37083248, '2021', '2021_JANUARY.json'),
#  (404264077, -36812895, '2021', '2021_JANUARY.json'),
#  (404273350, -37039263, '2021', '2021_JANUARY.json'),
#  (404245976, -36945293, '2021', '2021_JANUARY.json'),
#  (404264077, -36812895, '2021', '2021_JANUARY.json'),
#  (404245976, -36945293, '2021', '2021_JANUARY.json'),
#  (404264077, -36812895, '2021', '2021_JANUARY.json'),
#  (404409237, -36897093, '2021', '2021_JANUARY.json'),
#  (404391864, -36991711, '2021', '2021_JANUARY.json'),
#  (404409316, -37007404, '2021', '2021_JANUARY.json'),
#  (404384244, -36993565, '2021', '2021_JANUARY.json'),
#  (404264077, -36812895, '2021', '2021_JANUARY.json'),
#  (404253206, -36823617, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404249873, -37132456, '2021', '2021_FEBRUARY.json'),
#  (404305595, -37160778, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404346327, -37083248, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404315061, -37002712, '2021', '2021_FEBRUARY.json'),
#  (404332189, -37044703, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404245976, -36945293, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404216667, -36816667, '2021', '2021_FEBRUARY.json'),
#  (404246256, -36782296, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404245976, -36945293, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404244747, -36967539, '2021', '2021_FEBRUARY.json'),
#  (404675326, -37214333, '2021', '2021_FEBRUARY.json'),
#  (404661158, -37190785, '2021', '2021_FEBRUARY.json'),
#  (404249560, -37042570, '2021', '2021_FEBRUARY.json'),
#  (404248400, -37074200, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404086640, -36777905, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404086640, -36777905, '2021', '2021_FEBRUARY.json'),
#  (404268682, -36960092, '2021', '2021_FEBRUARY.json'),
#  (404294746, -36985680, '2021', '2021_FEBRUARY.json'),
#  (404277841, -36959238, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404262056, -36787278, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404675326, -37214333, '2021', '2021_FEBRUARY.json'),
#  (404245976, -36945293, '2021', '2021_FEBRUARY.json'),
#  (404262556, -37013807, '2021', '2021_FEBRUARY.json'),
#  (404269990, -37040303, '2021', '2021_FEBRUARY.json'),
#  (404248400, -37074200, '2021', '2021_FEBRUARY.json'),
#  (404382508, -37043393, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404245976, -36945293, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404256165, -36768287, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404252717, -36825579, '2021', '2021_FEBRUARY.json'),
#  (404275165, -36810310, '2021', '2021_FEBRUARY.json'),
#  (404346327, -37083248, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404277841, -36959238, '2021', '2021_FEBRUARY.json'),
#  (404208641, -37063862, '2021', '2021_FEBRUARY.json'),
#  (404212074, -37003257, '2021', '2021_FEBRUARY.json'),
#  (404226779, -36975885, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404245976, -36945293, '2021', '2021_FEBRUARY.json'),
#  (404252100, -36912500, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404250192, -36834507, '2021', '2021_FEBRUARY.json'),
#  (404246256, -36782296, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404250192, -36834507, '2021', '2021_FEBRUARY.json'),
#  (404253879, -36759079, '2021', '2021_FEBRUARY.json'),
#  (404294100, -37018900, '2021', '2021_FEBRUARY.json'),
#  (404277841, -36959238, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404264570, -36758400, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (405483416, -36239232, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404356638, -36882174, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404266196, -36812198, '2021', '2021_FEBRUARY.json'),
#  (404254349, -36738386, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404292130, -36972206, '2021', '2021_FEBRUARY.json'),
#  (404269990, -37040303, '2021', '2021_FEBRUARY.json'),
#  (404312380, -37038270, '2021', '2021_FEBRUARY.json'),
#  (404216986, -37046048, '2021', '2021_FEBRUARY.json'),
#  (404269990, -37040303, '2021', '2021_FEBRUARY.json'),
#  (404292130, -36972206, '2021', '2021_FEBRUARY.json'),
#  (404277841, -36959238, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404251704, -36828759, '2021', '2021_FEBRUARY.json'),
#  (404084512, -37007072, '2021', '2021_FEBRUARY.json'),
#  (404077661, -37043091, '2021', '2021_FEBRUARY.json'),
#  (404084512, -37007072, '2021', '2021_FEBRUARY.json'),
#  (404305595, -37160778, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404113845, -37083021, '2021', '2021_FEBRUARY.json'),
#  (404130109, -37118727, '2021', '2021_FEBRUARY.json'),
#  (404130179, -37134265, '2021', '2021_FEBRUARY.json'),
#  (404125885, -37154567, '2021', '2021_FEBRUARY.json'),
#  (404109627, -37131670, '2021', '2021_FEBRUARY.json'),
#  (404113845, -37083021, '2021', '2021_FEBRUARY.json'),
#  (404100600, -36975500, '2021', '2021_FEBRUARY.json'),
#  (404170136, -37034610, '2021', '2021_FEBRUARY.json'),
#  (404264077, -36812895, '2021', '2021_FEBRUARY.json'),
#  (404257971, -36906342, '2021', '2021_APRIL.json'),
#  (401402051, -34224950, '2021', '2021_APRIL.json'),
#  (400317495, -36102907, '2021', '2021_APRIL.json'),
#  (400364203, -36088655, '2021', '2021_APRIL.json'),
#  (400317495, -36102907, '2021', '2021_APRIL.json'),
#  (400545025, -35646358, '2021', '2021_APRIL.json'),
#  (400487518, -35707454, '2021', '2021_APRIL.json'),
#  (404012370, -36941040, '2021', '2021_APRIL.json'),
#  (403998874, -36947396, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (405640149, -36262271, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404284780, -36825950, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404269990, -37040303, '2021', '2021_APRIL.json'),
#  (404255400, -37039910, '2021', '2021_APRIL.json'),
#  (404277551, -37016713, '2021', '2021_APRIL.json'),
#  (404310340, -37019840, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404245976, -36945293, '2021', '2021_APRIL.json'),
#  (404265464, -36982508, '2021', '2021_APRIL.json'),
#  (404245976, -36945293, '2021', '2021_APRIL.json'),
#  (404234834, -36799063, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404245976, -36945293, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404245976, -36945293, '2021', '2021_APRIL.json'),
#  (410458900, -32252800, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404214609, -37055522, '2021', '2021_APRIL.json'),
#  (404215369, -37040616, '2021', '2021_APRIL.json'),
#  (404190511, -37076162, '2021', '2021_APRIL.json'),
#  (404102778, -37008333, '2021', '2021_APRIL.json'),
#  (403993312, -37013790, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404245976, -36945293, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404274718, -36993955, '2021', '2021_APRIL.json'),
#  (404277841, -36959238, '2021', '2021_APRIL.json'),
#  (404277841, -36959238, '2021', '2021_APRIL.json'),
#  (404268844, -37029310, '2021', '2021_APRIL.json'),
#  (404341012, -37082834, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404275165, -36810310, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404346327, -37083248, '2021', '2021_APRIL.json'),
#  (404298696, -37060568, '2021', '2021_APRIL.json'),
#  (404247711, -36781042, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (403974417, -36435170, '2021', '2021_APRIL.json'),
#  (404273844, -36857011, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404245976, -36945293, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404263494, -36966311, '2021', '2021_APRIL.json'),
#  (404260406, -36981039, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404305595, -37160778, '2021', '2021_APRIL.json'),
#  (404351152, -37168376, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404245976, -36945293, '2021', '2021_APRIL.json'),
#  (404675326, -37214333, '2021', '2021_APRIL.json'),
#  (404663174, -37192531, '2021', '2021_APRIL.json'),
#  (403985029, -36966472, '2021', '2021_APRIL.json'),
#  (403998874, -36947396, '2021', '2021_APRIL.json'),
#  (403998874, -36947396, '2021', '2021_APRIL.json'),
#  (404245976, -36945293, '2021', '2021_APRIL.json'),
#  (404282092, -37172920, '2021', '2021_APRIL.json'),
#  (404245976, -36945293, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (403998874, -36947396, '2021', '2021_APRIL.json'),
#  (403998874, -36947396, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404259518, -36778376, '2021', '2021_APRIL.json'),
#  (404225759, -36800270, '2021', '2021_APRIL.json'),
#  (404245976, -36945293, '2021', '2021_APRIL.json'),
#  (405449172, -36966174, '2021', '2021_APRIL.json'),
#  (404250822, -36923142, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404246256, -36782296, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (403919453, -36978834, '2021', '2021_APRIL.json'),
#  (403940379, -36980432, '2021', '2021_APRIL.json'),
#  (403998874, -36947396, '2021', '2021_APRIL.json'),
#  (404723097, -36824374, '2021', '2021_APRIL.json'),
#  (404572508, -36769695, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404233330, -36800980, '2021', '2021_APRIL.json'),
#  (404251840, -36767750, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404264984, -37037836, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404251153, -36805799, '2021', '2021_APRIL.json'),
#  (404245976, -36945293, '2021', '2021_APRIL.json'),
#  (404234001, -36909306, '2021', '2021_APRIL.json'),
#  (403998874, -36947396, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404253670, -36832480, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (403919453, -36978834, '2021', '2021_APRIL.json'),
#  (403923487, -36918489, '2021', '2021_APRIL.json'),
#  (403919453, -36978834, '2021', '2021_APRIL.json'),
#  (403911290, -36951562, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (403919453, -36978834, '2021', '2021_APRIL.json'),
#  (404234001, -36909306, '2021', '2021_APRIL.json'),
#  (404245976, -36945293, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (404258995, -36878997, '2021', '2021_APRIL.json'),
#  (403919453, -36978834, '2021', '2021_APRIL.json'),
#  (403941394, -36982631, '2021', '2021_APRIL.json'),
#  (403919453, -36978834, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (403919453, -36978834, '2021', '2021_APRIL.json'),
#  (403923487, -36918489, '2021', '2021_APRIL.json'),
#  (403919453, -36978834, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (403974417, -36435170, '2021', '2021_APRIL.json'),
#  (404246256, -36782296, '2021', '2021_APRIL.json'),
#  (404264077, -36812895, '2021', '2021_APRIL.json'),
#  (403919453, -36978834, '2021', '2021_APRIL.json'),
#  (403919453, -36978834, '2021', '2021_APRIL.json'),
#  (403941394, -36982631, '2021', '2021_APRIL.json'),
#  (403998874, -36947396, '2021', '2021_APRIL.json'),
#  (404088935, -37030323, '2021', '2021_MAY.json'),
#  (404098795, -37007812, '2021', '2021_MAY.json'),
#  (404245976, -36945293, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (404077828, -36510264, '2021', '2021_MAY.json'),
#  (403974417, -36435170, '2021', '2021_MAY.json'),
#  (404035543, -36283730, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403919453, -36978834, '2021', '2021_MAY.json'),
#  (403911290, -36951562, '2021', '2021_MAY.json'),
#  (404254095, -36829646, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403919453, -36978834, '2021', '2021_MAY.json'),
#  (404261494, -37011780, '2021', '2021_MAY.json'),
#  (404294224, -37027279, '2021', '2021_MAY.json'),
#  (404331080, -37039433, '2021', '2021_MAY.json'),
#  (404315159, -37036902, '2021', '2021_MAY.json'),
#  (404292130, -36972206, '2021', '2021_MAY.json'),
#  (404257484, -37031875, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403911290, -36951562, '2021', '2021_MAY.json'),
#  (403919453, -36978834, '2021', '2021_MAY.json'),
#  (404245976, -36945293, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403919453, -36978834, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (404258995, -36878997, '2021', '2021_MAY.json'),
#  (403919453, -36978834, '2021', '2021_MAY.json'),
#  (403941394, -36982631, '2021', '2021_MAY.json'),
#  (404123686, -37043242, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (404030213, -37130423, '2021', '2021_MAY.json'),
#  (404061947, -37047148, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (404251286, -36795703, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (404246256, -36782296, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403919453, -36978834, '2021', '2021_MAY.json'),
#  (403887770, -36998332, '2021', '2021_MAY.json'),
#  (403919453, -36978834, '2021', '2021_MAY.json'),
#  (404252383, -36743733, '2021', '2021_MAY.json'),
#  (404268480, -36757471, '2021', '2021_MAY.json'),
#  (404245976, -36945293, '2021', '2021_MAY.json'),
#  (404346327, -37083248, '2021', '2021_MAY.json'),
#  (404298696, -37060568, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (404258995, -36878997, '2021', '2021_MAY.json'),
#  (403919453, -36978834, '2021', '2021_MAY.json'),
#  (403911290, -36951562, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403919453, -36978834, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403923111, -36984630, '2021', '2021_MAY.json'),
#  (404050269, -36883126, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (404294224, -37027279, '2021', '2021_MAY.json'),
#  (404274718, -36993955, '2021', '2021_MAY.json'),
#  (404245976, -36945293, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403923111, -36984630, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403998874, -36947396, '2021', '2021_MAY.json'),
#  (404116498, -37316240, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (404258633, -36823841, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403975105, -37162551, '2021', '2021_MAY.json'),
#  (404113845, -37083021, '2021', '2021_MAY.json'),
#  (404123686, -37043242, '2021', '2021_MAY.json'),
#  (404158130, -36995630, '2021', '2021_MAY.json'),
#  (404148026, -36995115, '2021', '2021_MAY.json'),
#  (404212074, -37003257, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (404245976, -36945293, '2021', '2021_MAY.json'),
#  (404248654, -36891556, '2021', '2021_MAY.json'),
#  (403974417, -36435170, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403923111, -36984630, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403923111, -36984630, '2021', '2021_MAY.json'),
#  (403923111, -36984630, '2021', '2021_MAY.json'),
#  (403911290, -36951562, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403923111, -36984630, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403923111, -36984630, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403923111, -36984630, '2021', '2021_MAY.json'),
#  (403933333, -36977778, '2021', '2021_MAY.json'),
#  (404251290, -36845146, '2021', '2021_MAY.json'),
#  (404277841, -36959238, '2021', '2021_MAY.json'),
#  (404260406, -36981039, '2021', '2021_MAY.json'),
#  (404267621, -37028750, '2021', '2021_MAY.json'),
#  (404261494, -37011780, '2021', '2021_MAY.json'),
#  (404202472, -37057397, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (404251286, -36795703, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (404245976, -36945293, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (404251704, -36828759, '2021', '2021_MAY.json'),
#  (404305595, -37160778, '2021', '2021_MAY.json'),
#  (404249873, -37132456, '2021', '2021_MAY.json'),
#  (404168070, -37087490, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403923111, -36984630, '2021', '2021_MAY.json'),
#  (403920659, -36961166, '2021', '2021_MAY.json'),
#  (403923111, -36984630, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403923111, -36984630, '2021', '2021_MAY.json'),
#  (404382508, -37043393, '2021', '2021_MAY.json'),
#  (404382924, -37130614, '2021', '2021_MAY.json'),
#  (404339841, -37134165, '2021', '2021_MAY.json'),
#  (404382508, -37043393, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403923111, -36984630, '2021', '2021_MAY.json'),
#  (403911290, -36951562, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (404248464, -36738487, '2021', '2021_MAY.json'),
#  (404258584, -36812889, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403923111, -36984630, '2021', '2021_MAY.json'),
#  (404346327, -37083248, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (403923149, -36984963, '2021', '2021_MAY.json'),
#  (403923487, -36918489, '2021', '2021_MAY.json'),
#  (403923149, -36984963, '2021', '2021_MAY.json'),
#  (403941394, -36982631, '2021', '2021_MAY.json'),
#  (403916809, -36958237, '2021', '2021_MAY.json'),
#  (403998874, -36947396, '2021', '2021_MAY.json'),
#  (404096367, -37035841, '2021', '2021_MAY.json'),
#  (404082178, -36999984, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (404245976, -36945293, '2021', '2021_MAY.json'),
#  (404243221, -36959004, '2021', '2021_MAY.json'),
#  (404245976, -36945293, '2021', '2021_MAY.json'),
#  (403998874, -36947396, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (404245976, -36945293, '2021', '2021_MAY.json'),
#  (403923149, -36985035, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2021', '2021_MAY.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404251704, -36828759, '2019', '2019_DECEMBER.json'),
#  (404787588, -37204581, '2019', '2019_DECEMBER.json'),
#  (404800917, -37183539, '2019', '2019_DECEMBER.json'),
#  (404345452, -37083712, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404787588, -37204581, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404245976, -36945293, '2019', '2019_DECEMBER.json'),
#  (404374809, -36449978, '2019', '2019_DECEMBER.json'),
#  (404356900, -36428200, '2019', '2019_DECEMBER.json'),
#  (404277841, -36959238, '2019', '2019_DECEMBER.json'),
#  (404290600, -37021800, '2019', '2019_DECEMBER.json'),
#  (404303417, -37018245, '2019', '2019_DECEMBER.json'),
#  (404787588, -37204581, '2019', '2019_DECEMBER.json'),
#  (404800917, -37183539, '2019', '2019_DECEMBER.json'),
#  (404660029, -37190045, '2019', '2019_DECEMBER.json'),
#  (404675848, -37221474, '2019', '2019_DECEMBER.json'),
#  (404787588, -37204581, '2019', '2019_DECEMBER.json'),
#  (403950896, -37149674, '2019', '2019_DECEMBER.json'),
#  (403975105, -37162551, '2019', '2019_DECEMBER.json'),
#  (404254200, -36910100, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404675848, -37221474, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404245500, -36759100, '2019', '2019_DECEMBER.json'),
#  (404243719, -36761115, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404245976, -36945293, '2019', '2019_DECEMBER.json'),
#  (404242541, -36968251, '2019', '2019_DECEMBER.json'),
#  (404269736, -36958851, '2019', '2019_DECEMBER.json'),
#  (404282908, -37021960, '2019', '2019_DECEMBER.json'),
#  (404267191, -36836580, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (403974417, -36435170, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404345452, -37083712, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404245976, -36945293, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404312362, -36813966, '2019', '2019_DECEMBER.json'),
#  (404787588, -37204581, '2019', '2019_DECEMBER.json'),
#  (404675848, -37221474, '2019', '2019_DECEMBER.json'),
#  (404787588, -37204581, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404787588, -37204581, '2019', '2019_DECEMBER.json'),
#  (404675848, -37221474, '2019', '2019_DECEMBER.json'),
#  (404237354, -37055562, '2019', '2019_DECEMBER.json'),
#  (404230911, -37043788, '2019', '2019_DECEMBER.json'),
#  (404246952, -37072411, '2019', '2019_DECEMBER.json'),
#  (404675848, -37221474, '2019', '2019_DECEMBER.json'),
#  (404787588, -37204581, '2019', '2019_DECEMBER.json'),
#  (404675848, -37221474, '2019', '2019_DECEMBER.json'),
#  (404687168, -37230214, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404327656, -36826355, '2019', '2019_DECEMBER.json'),
#  (404356900, -36428200, '2019', '2019_DECEMBER.json'),
#  (404374809, -36449978, '2019', '2019_DECEMBER.json'),
#  (404245976, -36945293, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404787588, -37204581, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404152606, -36844995, '2019', '2019_DECEMBER.json'),
#  (404216359, -36816173, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404675848, -37221474, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404259153, -36813105, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404245976, -36945293, '2019', '2019_DECEMBER.json'),
#  (404256850, -36887400, '2019', '2019_DECEMBER.json'),
#  (404250100, -36832440, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404787588, -37204581, '2019', '2019_DECEMBER.json'),
#  (404675848, -37221474, '2019', '2019_DECEMBER.json'),
#  (404245976, -36945293, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404787588, -37204581, '2019', '2019_DECEMBER.json'),
#  (404800917, -37183539, '2019', '2019_DECEMBER.json'),
#  (404675848, -37221474, '2019', '2019_DECEMBER.json'),
#  (404654820, -37177309, '2019', '2019_DECEMBER.json'),
#  (404675848, -37221474, '2019', '2019_DECEMBER.json'),
#  (404292130, -36972210, '2019', '2019_DECEMBER.json'),
#  (404245976, -36945293, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404787588, -37204581, '2019', '2019_DECEMBER.json'),
#  (404245976, -36945293, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404787588, -37204581, '2019', '2019_DECEMBER.json'),
#  (404800917, -37183539, '2019', '2019_DECEMBER.json'),
#  (404675848, -37221474, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404787588, -37204581, '2019', '2019_DECEMBER.json'),
#  (404313359, -37067761, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404345452, -37083712, '2019', '2019_DECEMBER.json'),
#  (404298001, -37057108, '2019', '2019_DECEMBER.json'),
#  (404246256, -36782296, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404252917, -36823782, '2019', '2019_DECEMBER.json'),
#  (404247984, -36799636, '2019', '2019_DECEMBER.json'),
#  (404243788, -36747476, '2019', '2019_DECEMBER.json'),
#  (404246256, -36782296, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (403007350, -40274170, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404245976, -36945293, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404243412, -36958754, '2019', '2019_DECEMBER.json'),
#  (404245976, -36945293, '2019', '2019_DECEMBER.json'),
#  (404252100, -36912500, '2019', '2019_DECEMBER.json'),
#  (404259565, -36743542, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404267115, -36987762, '2019', '2019_DECEMBER.json'),
#  (404245976, -36945293, '2019', '2019_DECEMBER.json'),
#  (404277841, -36959238, '2019', '2019_DECEMBER.json'),
#  (404301670, -37099910, '2019', '2019_DECEMBER.json'),
#  (404290600, -37021800, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404345452, -37083712, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404258125, -36838437, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404251704, -36828759, '2019', '2019_DECEMBER.json'),
#  (404113845, -37083021, '2019', '2019_DECEMBER.json'),
#  (404264077, -36812895, '2019', '2019_DECEMBER.json'),
#  (404251704, -36828759, '2019', '2019_DECEMBER.json'),
#  (404106445, -37074888, '2019', '2019_DECEMBER.json'),
#  (404119851, -37057319, '2019', '2019_DECEMBER.json'),
#  (404123686, -37043242, '2019', '2019_DECEMBER.json'),
#  (404245976, -36945293, '2019', '2019_DECEMBER.json'),
#  (405639339, -36261900, '2019', '2019_DECEMBER.json'),
#  (404237794, -37020716, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404251704, -36828759, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404268337, -36757525, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404270047, -37040101, '2019', '2019_MAY.json'),
#  (404261175, -37078297, '2019', '2019_MAY.json'),
#  (404221160, -37074190, '2019', '2019_MAY.json'),
#  (404237498, -37072732, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404245976, -36945293, '2019', '2019_MAY.json'),
#  (404345452, -37083712, '2019', '2019_MAY.json'),
#  (404259153, -36813105, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404234834, -36799063, '2019', '2019_MAY.json'),
#  (404788647, -37202590, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (403402272, -37330555, '2019', '2019_MAY.json'),
#  (405466983, -36943619, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404788647, -37202590, '2019', '2019_MAY.json'),
#  (404800917, -37183539, '2019', '2019_MAY.json'),
#  (404380350, -36766893, '2019', '2019_MAY.json'),
#  (404246256, -36782296, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404233259, -36909632, '2019', '2019_MAY.json'),
#  (405466983, -36943619, '2019', '2019_MAY.json'),
#  (404788647, -37202590, '2019', '2019_MAY.json'),
#  (404246256, -36782296, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404788647, -37202590, '2019', '2019_MAY.json'),
#  (404800917, -37183539, '2019', '2019_MAY.json'),
#  (404345452, -37083712, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404788647, -37202590, '2019', '2019_MAY.json'),
#  (404800917, -37183539, '2019', '2019_MAY.json'),
#  (404380350, -36766893, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404261494, -37011780, '2019', '2019_MAY.json'),
#  (404148933, -36995170, '2019', '2019_MAY.json'),
#  (404125824, -37153975, '2019', '2019_MAY.json'),
#  (404181485, -37093516, '2019', '2019_MAY.json'),
#  (404217861, -37087615, '2019', '2019_MAY.json'),
#  (404081985, -37011689, '2019', '2019_MAY.json'),
#  (404098800, -36926300, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404445565, -37122785, '2019', '2019_MAY.json'),
#  (404788647, -37202590, '2019', '2019_MAY.json'),
#  (404846772, -37076729, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (405466983, -36943619, '2019', '2019_MAY.json'),
#  (404565284, -37121634, '2019', '2019_MAY.json'),
#  (404788647, -37202590, '2019', '2019_MAY.json'),
#  (404345452, -37083712, '2019', '2019_MAY.json'),
#  (404313359, -37067761, '2019', '2019_MAY.json'),
#  (404277841, -36959238, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404277841, -36959238, '2019', '2019_MAY.json'),
#  (403975105, -37162551, '2019', '2019_MAY.json'),
#  (403980136, -37282341, '2019', '2019_MAY.json'),
#  (403980136, -37282341, '2019', '2019_MAY.json'),
#  (403980136, -37282341, '2019', '2019_MAY.json'),
#  (403980136, -37282341, '2019', '2019_MAY.json'),
#  (403980136, -37282341, '2019', '2019_MAY.json'),
#  (403975105, -37162551, '2019', '2019_MAY.json'),
#  (404321830, -36732940, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (403415903, -37124913, '2019', '2019_MAY.json'),
#  (405466983, -36943619, '2019', '2019_MAY.json'),
#  (404466060, -36922869, '2019', '2019_MAY.json'),
#  (404565284, -37121634, '2019', '2019_MAY.json'),
#  (404788647, -37202590, '2019', '2019_MAY.json'),
#  (404800917, -37183539, '2019', '2019_MAY.json'),
#  (404345452, -37083712, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404233259, -36909632, '2019', '2019_MAY.json'),
#  (405466983, -36943619, '2019', '2019_MAY.json'),
#  (404866800, -36986100, '2019', '2019_MAY.json'),
#  (404788647, -37202590, '2019', '2019_MAY.json'),
#  (404800917, -37183539, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404132216, -36964250, '2019', '2019_MAY.json'),
#  (404169473, -37035285, '2019', '2019_MAY.json'),
#  (404197380, -37018893, '2019', '2019_MAY.json'),
#  (404261494, -37011780, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404345452, -37083712, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404377585, -36792407, '2019', '2019_MAY.json'),
#  (404787588, -37204581, '2019', '2019_MAY.json'),
#  (404382508, -37043393, '2019', '2019_MAY.json'),
#  (404160028, -37004754, '2019', '2019_MAY.json'),
#  (404193371, -36930836, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (405466983, -36943619, '2019', '2019_MAY.json'),
#  (404787588, -37204581, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404246256, -36782296, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (405466983, -36943619, '2019', '2019_MAY.json'),
#  (404251704, -36828759, '2019', '2019_MAY.json'),
#  (404300843, -36963602, '2019', '2019_MAY.json'),
#  (404272710, -36953820, '2019', '2019_MAY.json'),
#  (404787588, -37204581, '2019', '2019_MAY.json'),
#  (404465109, -37118033, '2019', '2019_MAY.json'),
#  (404565284, -37121634, '2019', '2019_MAY.json'),
#  (404380350, -36766893, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (405466983, -36943619, '2019', '2019_MAY.json'),
#  (404788647, -37202590, '2019', '2019_MAY.json'),
#  (404800917, -37183539, '2019', '2019_MAY.json'),
#  (404380350, -36766893, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404788647, -37202590, '2019', '2019_MAY.json'),
#  (404800917, -37183539, '2019', '2019_MAY.json'),
#  (404380350, -36766893, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404114707, -37020732, '2019', '2019_MAY.json'),
#  (404132216, -36964250, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404246256, -36782296, '2019', '2019_MAY.json'),
#  (404230733, -36797763, '2019', '2019_MAY.json'),
#  (404006669, -36351894, '2019', '2019_MAY.json'),
#  (404036634, -36283153, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404245976, -36945293, '2019', '2019_MAY.json'),
#  (404267754, -36993687, '2019', '2019_MAY.json'),
#  (404787588, -37204581, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404788647, -37202590, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404788647, -37202590, '2019', '2019_MAY.json'),
#  (404345452, -37083712, '2019', '2019_MAY.json'),
#  (404298001, -37057108, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404723097, -36824374, '2019', '2019_MAY.json'),
#  (405466983, -36943619, '2019', '2019_MAY.json'),
#  (404866800, -36986100, '2019', '2019_MAY.json'),
#  (404787588, -37204581, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404264077, -36812895, '2019', '2019_MAY.json'),
#  (404800917, -37183539, '2019', '2019_MAY.json'),
#  (404380397, -36912419, '2019', '2019_MAY.json'),
#  (404245976, -36945293, '2019', '2019_MAY.json'),
#  (404206062, -36989758, '2019', '2019_MAY.json'),
#  (357843316, -58131351, '2019', '2019_APRIL.json'),
#  (357265955, -59150683, '2019', '2019_APRIL.json'),
#  (404983322, -35675982, '2019', '2019_APRIL.json'),
#  (404465109, -37118033, '2019', '2019_APRIL.json'),
#  (404788647, -37202590, '2019', '2019_APRIL.json'),
#  (404800502, -37075454, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404788647, -37202590, '2019', '2019_APRIL.json'),
#  (404385463, -37041650, '2019', '2019_APRIL.json'),
#  (404177383, -37080185, '2019', '2019_APRIL.json'),
#  (404160722, -37010974, '2019', '2019_APRIL.json'),
#  (404304502, -37012947, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (405466983, -36943619, '2019', '2019_APRIL.json'),
#  (404788647, -37202590, '2019', '2019_APRIL.json'),
#  (404380397, -36912419, '2019', '2019_APRIL.json'),
#  (404245976, -36945293, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (405466983, -36943619, '2019', '2019_APRIL.json'),
#  (404849600, -37002600, '2019', '2019_APRIL.json'),
#  (404788647, -37202590, '2019', '2019_APRIL.json'),
#  (404675848, -37221474, '2019', '2019_APRIL.json'),
#  (404665209, -37192912, '2019', '2019_APRIL.json'),
#  (404574942, -36943243, '2019', '2019_APRIL.json'),
#  (404292347, -36987046, '2019', '2019_APRIL.json'),
#  (404268805, -37030899, '2019', '2019_APRIL.json'),
#  (404238652, -37013569, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404275298, -36767683, '2019', '2019_APRIL.json'),
#  (404245976, -36945293, '2019', '2019_APRIL.json'),
#  (404345452, -37083712, '2019', '2019_APRIL.json'),
#  (404298001, -37057108, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404788647, -37202590, '2019', '2019_APRIL.json'),
#  (404269736, -36958851, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (405466983, -36943619, '2019', '2019_APRIL.json'),
#  (404788647, -37202590, '2019', '2019_APRIL.json'),
#  (404274739, -36993545, '2019', '2019_APRIL.json'),
#  (404268759, -37029317, '2019', '2019_APRIL.json'),
#  (404263624, -37014251, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404788647, -37202590, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404370020, -36793384, '2019', '2019_APRIL.json'),
#  (404804210, -37165510, '2019', '2019_APRIL.json'),
#  (404788647, -37202590, '2019', '2019_APRIL.json'),
#  (404274739, -36993545, '2019', '2019_APRIL.json'),
#  (404268759, -37029317, '2019', '2019_APRIL.json'),
#  (404263624, -37014251, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404788647, -37202590, '2019', '2019_APRIL.json'),
#  (405640200, -36262300, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404278534, -37039891, '2019', '2019_APRIL.json'),
#  (404257544, -37043747, '2019', '2019_APRIL.json'),
#  (404290543, -37021816, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404345452, -37083712, '2019', '2019_APRIL.json'),
#  (404298001, -37057108, '2019', '2019_APRIL.json'),
#  (404246256, -36782296, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404261494, -37011780, '2019', '2019_APRIL.json'),
#  (404138410, -37030180, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404270047, -37040101, '2019', '2019_APRIL.json'),
#  (404268759, -37029317, '2019', '2019_APRIL.json'),
#  (404261494, -37011780, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (402236808, -33345651, '2019', '2019_APRIL.json'),
#  (395165569, -17536122, '2019', '2019_APRIL.json'),
#  (390873402, -2485733, '2019', '2019_APRIL.json'),
#  (388407960, 1209780, '2019', '2019_APRIL.json'),
#  (388322035, 1203284, '2019', '2019_APRIL.json'),
#  (388396517, 1107179, '2019', '2019_APRIL.json'),
#  (388369100, 1100050, '2019', '2019_APRIL.json'),
#  (388384382, 1082937, '2019', '2019_APRIL.json'),
#  (388405408, 1093859, '2019', '2019_APRIL.json'),
#  (388322035, 1203284, '2019', '2019_APRIL.json'),
#  (387514482, 2239401, '2019', '2019_APRIL.json'),
#  (387741709, 1889661, '2019', '2019_APRIL.json'),
#  (394560422, -9045403, '2019', '2019_APRIL.json'),
#  (395191820, -16559408, '2019', '2019_APRIL.json'),
#  (395167617, -16684972, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404071782, -36889689, '2019', '2019_APRIL.json'),
#  (404983322, -35675982, '2019', '2019_APRIL.json'),
#  (406437225, -31819302, '2019', '2019_APRIL.json'),
#  (406286990, -31859457, '2019', '2019_APRIL.json'),
#  (410467272, -32266935, '2019', '2019_APRIL.json'),
#  (410343412, -32167158, '2019', '2019_APRIL.json'),
#  (410458900, -32252800, '2019', '2019_APRIL.json'),
#  (410467272, -32266935, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404345452, -37083712, '2019', '2019_APRIL.json'),
#  (404298001, -37057108, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404788647, -37202590, '2019', '2019_APRIL.json'),
#  (404800917, -37183539, '2019', '2019_APRIL.json'),
#  (404345452, -37083712, '2019', '2019_APRIL.json'),
#  (404298001, -37057108, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (405466983, -36943619, '2019', '2019_APRIL.json'),
#  (404788647, -37202590, '2019', '2019_APRIL.json'),
#  (404259153, -36813105, '2019', '2019_APRIL.json'),
#  (404245976, -36945293, '2019', '2019_APRIL.json'),
#  (405466983, -36943619, '2019', '2019_APRIL.json'),
#  (404788647, -37202590, '2019', '2019_APRIL.json'),
#  (404345452, -37083712, '2019', '2019_APRIL.json'),
#  (404302591, -37091799, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (405466983, -36943619, '2019', '2019_APRIL.json'),
#  (404866800, -36986100, '2019', '2019_APRIL.json'),
#  (404788647, -37202590, '2019', '2019_APRIL.json'),
#  (404380350, -36766893, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404254729, -37018412, '2019', '2019_APRIL.json'),
#  (404262510, -37013780, '2019', '2019_APRIL.json'),
#  (404261839, -37021050, '2019', '2019_APRIL.json'),
#  (404257544, -37043747, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404380350, -36766893, '2019', '2019_APRIL.json'),
#  (404788647, -37202590, '2019', '2019_APRIL.json'),
#  (404259153, -36813105, '2019', '2019_APRIL.json'),
#  (404090103, -37017141, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404266197, -36996624, '2019', '2019_APRIL.json'),
#  (404245976, -36945293, '2019', '2019_APRIL.json'),
#  (404345452, -37083712, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404368659, -36778256, '2019', '2019_APRIL.json'),
#  (404788647, -37202590, '2019', '2019_APRIL.json'),
#  (404259153, -36813105, '2019', '2019_APRIL.json'),
#  (404233259, -36909632, '2019', '2019_APRIL.json'),
#  (404723097, -36824374, '2019', '2019_APRIL.json'),
#  (405466983, -36943619, '2019', '2019_APRIL.json'),
#  (404787588, -37204581, '2019', '2019_APRIL.json'),
#  (404804210, -37165510, '2019', '2019_APRIL.json'),
#  (404788647, -37202590, '2019', '2019_APRIL.json'),
#  (404380350, -36766893, '2019', '2019_APRIL.json'),
#  (404264077, -36812895, '2019', '2019_APRIL.json'),
#  (404290543, -37021816, '2019', '2019_APRIL.json'),
#  (404270047, -37040101, '2019', '2019_APRIL.json'),
#  (404245976, -36945293, '2019', '2019_SEPTEMBER.json'),
#  (404264077, -36812895, '2019', '2019_SEPTEMBER.json'),
#  (404787588, -37204581, '2019', '2019_SEPTEMBER.json'),
#  (404293756, -37020674, '2019', '2019_SEPTEMBER.json'),
#  (404269990, -37040303, '2019', '2019_SEPTEMBER.json'),
#  (404290543, -37021816, '2019', '2019_SEPTEMBER.json'),
#  (404675848, -37221474, '2019', '2019_SEPTEMBER.json'),
#  (404264077, -36812895, '2019', '2019_SEPTEMBER.json'),
#  (404787588, -37204581, '2019', '2019_SEPTEMBER.json'),
#  (404891130, -37006010, '2019', '2019_SEPTEMBER.json'),
#  (404675848, -37221474, '2019', '2019_SEPTEMBER.json'),
#  (404246256, -36782296, '2019', '2019_SEPTEMBER.json'),
#  (404264077, -36812895, '2019', '2019_SEPTEMBER.json'),
#  (404787588, -37204581, '2019', '2019_SEPTEMBER.json'),
#  (404264077, -36812895, '2019', '2019_SEPTEMBER.json'),
#  (404787588, -37204581, '2019', '2019_SEPTEMBER.json'),
#  (404246256, -36782296, '2019', '2019_SEPTEMBER.json'),
#  (404264077, -36812895, '2019', '2019_SEPTEMBER.json'),
#  ...]

# %%
u = open(Takeout_dir + '/' + 'Historial de ubicaciones' +'/'+'Semantic Location History')
ubica_json = json.load(u)

# %%
for i in (0,4):
    'ls'+i = i

# %%
cambio
